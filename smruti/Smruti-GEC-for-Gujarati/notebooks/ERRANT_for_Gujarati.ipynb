# %% [markdown]
# # morph pos model

# %%
# !pip install --quiet transformers==4.37
# !pip install --quiet sentence-transformers==2.7.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 71.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 49.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.37.0 which is incompatible.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ^C
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-1-3397389130.py", line 2, in <cell line: 0>
#     get_ipython().system('pip install --quiet sentence-transformers==2.7.0')
#   File "/usr/local/lib/python3.11/dist-packages/google/colab/_shell.py", line 152, in system
#     _pip.print_previous_import_warning(output)
#   File "/usr/local/lib/python3.11/dist-packages/google/colab/_pip.py", line 56, in print_previous_import_warning
#     packages = _previously_imported_packages(output)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/colab/_pip.py", line 50, in _previously_imported_packages
#     installed = set(_extract_toplevel_packages(pip_output))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/colab/_pip.py", line 39, in _extract_toplevel_packages
#     for m, ps in importlib.metadata.packages_distributions().items():
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/metadata/__init__.py", line 1076, in packages_distributions
#     pkg_to_dist[pkg].append(dist.metadata['Name'])
#                             ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/importlib_metadata/__init__.py", line 527, in metadata
#     self.read_text('METADATA')
#   File "/usr/local/lib/python3.11/dist-packages/importlib_metadata/__init__.py", line 998, in read_text
#     return self._path.joinpath(filename).read_text(encoding='utf-8')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/pathlib.py", line 1059, in read_text
#     return f.read()
#            ^^^^^^^^
#   File "<frozen codecs>", line 319, in decode
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1684, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 948, in getsourcefile
#     module = getmodule(object, filename)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 997, in getmodule
#     os.path.realpath(f)] = module.__name__
#     ^^^^^^^^^^^^^^^^^^^
#   File "<frozen posixpath>", line 416, in realpath
#   File "<frozen posixpath>", line 440, in _joinrealpath
#   File "<frozen posixpath>", line 64, in isabs
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-1-3397389130.py", line 2, in <cell line: 0>
#     get_ipython().system('pip install --quiet sentence-transformers==2.7.0')
#   File "/usr/local/lib/python3.11/dist-packages/google/colab/_shell.py", line 152, in system
#     _pip.print_previous_import_warning(output)
#   File "/usr/local/lib/python3.11/dist-packages/google/colab/_pip.py", line 56, in print_previous_import_warning
#     packages = _previously_imported_packages(output)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/colab/_pip.py", line 50, in _previously_imported_packages
#     installed = set(_extract_toplevel_packages(pip_output))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/colab/_pip.py", line 39, in _extract_toplevel_packages
#     for m, ps in importlib.metadata.packages_distributions().items():
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/metadata/__init__.py", line 1076, in packages_distributions
#     pkg_to_dist[pkg].append(dist.metadata['Name'])
#                             ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/importlib_metadata/__init__.py", line 527, in metadata
#     self.read_text('METADATA')
#   File "/usr/local/lib/python3.11/dist-packages/importlib_metadata/__init__.py", line 998, in read_text
#     return self._path.joinpath(filename).read_text(encoding='utf-8')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/pathlib.py", line 1059, in read_text
#     return f.read()
#            ^^^^^^^^
#   File "<frozen codecs>", line 319, in decode
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1684, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 948, in getsourcefile
#     module = getmodule(object, filename)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 994, in getmodule
#     f = getabsfile(module)
#         ^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 963, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 945, in getsourcefile
#     if os.path.exists(filename):
#        ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen genericpath>", line 19, in exists
# KeyboardInterrupt
# KeyboardInterrupt

# %%
import torch.nn as nn
import numpy as np
import torch
from transformers import AutoTokenizer
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# %%
NA='NA'
MAX_LENGTH=120
base_path='/content/drive/MyDrive/AI-ML-NLP/NLP/models/'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)

# %%
all_feature_values={
    'pos':[
      NA,'DM_DMI', 'CC_CCD', 'PSP', 'PR_PRQ', 'RP_RPD', 'PR_PRP', 'DM_DMQ', 'RB', 'QT_QTO', 'JJ', 'RD_ECH', 'PR_PRF', 'N_NNP', 'N_NN', 'RP_CL', 'V_VM', 'DM_DMD', 'RP_INTF', 'QT_QTC', 'RP_INJ', 'PR_PRC', 'V_VAUX_VNP', 'RD_PUNC', 'PR_PRI', 'PR_PRL', 'DM_DMR', 'CC_CCS_UT', 'RD_RDF', 'N_NST', 'RP_NEG', 'RD_SYM', 'V_VAUX', 'QT_QTF', 'CC_CCS', 'Value'
    ],
    'gender':[
        NA,'MASC','FEM','NEUT'
    ],
    'number':[
        NA,'SG','PL'
    ],
    'type':[
        NA,'LGSPEC02','LGSPEC01','LGSPEC03'
    ],
    'person':[
        NA,'1','2','3'
    ],
    'tense':[
        NA,'PST','FUT'
        # is present tense is not there?
    ],
    'case':[
        NA,'ERG', 'GEN', 'NOM', 'DAT', 'LOC','ABL'
    ],
    'aspect':[
        NA,'NFIN'
    ],
    # what is NFIN
}

feature_values={
    'pos':[
      NA,'DM_DMI', 'CC_CCD', 'PSP', 'PR_PRQ', 'RP_RPD', 'PR_PRP', 'DM_DMQ', 'RB', 'QT_QTO', 'JJ', 'RD_ECH', 'PR_PRF', 'N_NNP', 'N_NN', 'RP_CL', 'V_VM', 'DM_DMD', 'RP_INTF', 'QT_QTC', 'RP_INJ', 'PR_PRC', 'V_VAUX_VNP', 'RD_PUNC', 'PR_PRI', 'PR_PRL', 'DM_DMR', 'CC_CCS_UT', 'RD_RDF', 'N_NST', 'RP_NEG', 'RD_SYM', 'V_VAUX', 'QT_QTF', 'CC_CCS', 'Value'
    ],
    'gender':[
        NA,'MASC','FEM','NEUT'
    ],
    'number':[
        NA,'SG','PL'
    ],
    'type':[
        NA,'LGSPEC02','LGSPEC01','LGSPEC03'
    ],
    'person':[
        NA,'1','2','3'
    ],
    'tense':[
        NA,'PST','FUT'
        # is present tense is not there?
    ],
    'case':[
        NA,'ERG', 'GEN', 'NOM', 'DAT', 'LOC','ABL'
    ],
    'aspect':[
        NA,'NFIN'
    ],
    # what is NFIN
}

feature_seq=list(feature_values.keys())
EXTRA_TOKEN=[-100]*len(feature_seq)

total_number_of_features=0
feature_value2id={}
feature_id2value={}
feature_start_range={}

start_range=0
for key,values in feature_values.items():
  feature_value2id[key]={}
  feature_start_range[key]=start_range
  for i,value in enumerate(values):
    feature_value2id[key][value]=i+start_range
  feature_id2value[key]={(y-start_range):x for x,y in feature_value2id[key].items()}
  start_range+=len(values)
  total_number_of_features+=len(values)

print(feature_value2id)
print(feature_id2value)
print(total_number_of_features)
print(feature_start_range)


number_of_labels=total_number_of_features

# %%
tokenizer = AutoTokenizer.from_pretrained("l3cube-pune/gujarati-bert")

# %%
class CustomTokenClassificationModel(nn.Module):
    def __init__(self, bert_model, feature_seq):
        super(CustomTokenClassificationModel, self).__init__()
        self.bert_model = bert_model

        self.module_list = nn.ModuleList()

        for key in feature_seq:
          num_classes = len(feature_values[key])
          module = nn.Linear(number_of_labels, num_classes)
          self.module_list.append(module)

    def forward(self, input_ids, attention_mask):
        # 1) Run BERT to get last_hidden_state (shape: [B, L, 768])
        outputs = self.bert_model(input_ids=input_ids, attention_mask=attention_mask)
        hidden_states = outputs.logits

        # 2) Run each head on the 768‐dim embeddings
        logits_list = []
        for head in self.module_list:
            logits = head(hidden_states)
            # logits has shape [batch_size, seq_len, num_classes_for_that_feature]
            logits_list.append(logits)

        # 3) Return the list of all feature‐head logits
        return logits_list

class PosMorphClassificationModel(nn.Module):
    def __init__(self, custom_model, feature_seq):
        super(PosMorphClassificationModel, self).__init__()
        self.custom_model = custom_model

    def forward(self, input_ids, attention_mask):
        return self.custom_model(
              input_ids,
              attention_mask=attention_mask
        )

import torch
import torch.nn.functional as F

class MorphAnalysis:
    def __init__(self, tokenizer, inference_model, feature_seq, feature_id2value, max_length,NA):
        self.tokenizer = tokenizer
        self.inference_model = inference_model
        self.feature_seq = feature_seq
        self.feature_id2value = feature_id2value
        self.max_length = max_length
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.NA = NA

    def prepare_mask(self, word_ids):
        mask = []
        last = None
        for i in word_ids:
            if i is None or i == last:
                mask.append(0)
            else:
                mask.append(1)
            last = i
        return mask

    def tokenize_sentence(self, sentence, splitted=False):
        if not splitted:
            tokens = sentence.split(' ')
        else:
            tokens = sentence

        tokenized_inputs = self.tokenizer(
            tokens,
            padding='max_length',
            truncation=True,
            is_split_into_words=True,
            max_length=self.max_length,
        )
        mask = self.prepare_mask(tokenized_inputs.word_ids(0))
        sample = {
            "tokens": tokens,
            "mask": mask,
            "input_ids": tokenized_inputs['input_ids'],
            "attention_mask": tokenized_inputs['attention_mask']
        }
        return sample

    def prepare_output(self, sample):
        tokens = sample['tokens']
        output = []

        for i, token in enumerate(tokens):
          features = {}
          for feat in self.feature_seq:
            feat_val = sample[feat][i]
            if feat_val != self.NA:
              features[feat] = feat_val
          output.append((token, features))
        return output

    def infer(self, sentence):
        batch = self.tokenize_sentence(sentence)

        input_ids = torch.tensor([batch["input_ids"]]).to(self.device)
        attention_mask = torch.tensor([batch["attention_mask"]]).to(self.device)
        mask = torch.tensor([batch['mask']]).to(self.device)

        logits_list = self.inference_model(input_ids, attention_mask=attention_mask)

        curr_sample = {
            "tokens": batch["tokens"],
        }

        for i, logits in enumerate(logits_list):
            key = self.feature_seq[i]
            curr_mask = (mask != 0)
            valid_logits = logits[curr_mask]
            probabilities = F.softmax(valid_logits, dim=-1)
            valid_predicted_labels = torch.argmax(probabilities, dim=-1)
            curr_id2value_map = self.feature_id2value[key]
            curr_sample[key] = [curr_id2value_map[x] for x in valid_predicted_labels.tolist()]


        output = self.prepare_output(curr_sample)
        return output

# %%
# prompt: Write a simple tokenizer

def simple_tokenizer(text):
    """
    A simple function to tokenize a string into a list of words.

    Args:
        text (str): The input string to tokenize.

    Returns:
        list: A list of words (tokens).
    """
    return text.split()

# %%
inference_input_file_path="/content/drive/MyDrive/NLP Gujarati POS & Morph Analysis/POS_MORPH_MODEL/trained_model_binary_file/GUJ_POS_MORPH_ANAYLISIS_WRAPPER-v6.0-model.pth"
inference_checkpoint_path = inference_input_file_path

inference_model=torch.load(inference_checkpoint_path,map_location=device, weights_only=False)
inference_model.eval()
inference_model.to(device)

# %%
model = MorphAnalysis(tokenizer, inference_model, feature_seq, feature_id2value, MAX_LENGTH,NA)

# %%
sentences = [
    "બાળકો ક્રિકેટનો ખેલ રમી રહ્યા છે",
    "તેમણે મને ખેલ કર્યો",
    "મહેરબાની કરીને આ કામ કરો",
    "મારે એક નવો કરો મળી ગયો છે",
    "હું ભાત પાકીશ",
    "આ પાક ખૂબ જ સ્વાદિષ્ટ છે",
    "વિરાટ ક્રિકેટર છે",
    "આ કાર્ય ખુબ જ વિરાટ હતું",
    "રમેશ તું વિચાર",
    "વિચાર આજે ગૃહકાર્ય નથી લાવ્યો",
    "સ્વામી રાજી થયા",
    "રાજી એ શાક ખાધું",
    "બાળકો હરિત હસ્તો લહેવાનો ઇચ્છુક છે",
    "હરિત પર્વાઓ એટલે બહારમાં વસ્ત્રો ધરાવવાનો આનંદ મને મળે છે",
    "મેં નેતાગીરી પોતાની પાસે રાખી",
    "લક્ષ્મીજીએ બલી રાજા ને રાખી બાંધી",
    "તું મને મોબાઈલ નીચે મૂક",
    "અકિરાને મૂક ભાષા આવડતી હતી",
    "ગઈકાલે ક્રિષ્ણા આવી",
    "ગઈકાલે ક્રિષ્ણા આવ્યો",
    "મને શ્રી કૃષ્ણ ની વાતો ગમે",
    "કનૈયો કૃષ્ણ વર્ણનો હોવા છતાં ખુબ જ મોહક લાગે",
    "માછીમારે માછલીને મારી નાખી",
    "મારી માછલી મેં તળાવમાં નાખી",
    "મેં તળાવમાં મારી માછલી નાખી",
    "મેં તળાવમાં માછલી મારી નાખી",
    "તમે શાંતિથી બોલો",
    "શાંતિ એ ખુબ સ્વાદિષ્ટ ભોજન પિરસીયું",
    "ઋષિએ તપ કર્યું",
    "તપ આજે જ ઘરે આવ્યો",
    "વાહ શું વાત છે!",
    "તમે વાહિયાત વાત કરો છો",
    "તારે ફોનનું શું કામ છે?",
    "કામ દેવ નો જન્મ શ્રીકૃષ્ણ અને રુક્મણી ને ત્યાં પ્રદ્યુમ્ન સ્વરૂપે જન્મ થયો",
    "શ્રીકૃષ્ણ ખુબ સુંદર લાગે છે",
    "સુંદર વાકાણી દયાનો સગો ભાઈ છે",
    "મનીશે સાચી વાત કરી",
    "સાચી ને ઊંઘમાં બોલવાની ટેવ છે",
    "રવિ મોડો આવ્યો",
    "કાલે રવિ વાર છે",
    "નવરંગ ચૂંદડી માને શોભે",
    "નવરંગ ચૂંદડી મા ને શોભે",
    "નવ રંગ થી રંગોળી પાળી"
]

for i,sentence in enumerate(sentences):
  print(i+1,".",sentence)
  print(model.infer(sentence))
  print("------------------------------------------------")

# %% [markdown]
# # VGD3626/errant-for-gujarati

# %%
# !pip install --quiet transformers==4.37
# !pip install --quiet sentence-transformers==2.7.0
# !pip install --quiet python-Levenshtein
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 85.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 85.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.37.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 110.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 67.4 MB/s eta 0:00:00

# %%
# !git clone https://github.com/VGD3626/errant-for-gujarati.git
# %cd errant-for-gujarati
# !pip install --quiet -e .
# Out:
# Cloning into 'errant-for-gujarati'...
# remote: Enumerating objects: 586, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 586 (delta 177), reused 148 (delta 135), pack-reused 358 (from 1)
# Receiving objects: 100% (586/586), 2.57 MiB | 5.71 MiB/s, done.
# Resolving deltas: 100% (376/376), done.
# /content/errant-for-gujarati
#   Preparing metadata (setup.py) ... done

# %%
import re, json
stopwords = []
def GujaratiTokenizer(data, keep_stopwords=True):
    data = re.sub(r'([”“.,;:\'\\"!?%#@*<>|\+\-\(\)])', r' \1 ', data)
    data = re.sub(r"   ", ' ', data)
    data = re.sub(r'…', " ", data)
    data = re.sub(r'[‘’]', "'", data)
    data = re.sub(r"[”“]", r'"', data)
    data = re.split(r'[ -]', data)
    words = []

    if not keep_stopwords:
        for word in data:
            if word and word not in stopwords:
                words.append(word)
        return words

    for i in data:
        if i:
            words.append(i)
    return words

# %%
def tokanize_and_join(x):
  return ' '.join(GujaratiTokenizer(x))

# %%
import json
import os
input_files = ['/content/drive/MyDrive/Smruti-GEC-for-Gujarati/results/synthetic/cot_with_m1&m2_k1=7_k2=1.json']
# input_files = ['/content/drive/MyDrive/Smruti-GEC-for-Gujarati/data/synthetic_eval_set.json']
# Open output files
with open('/content/cor.txt', 'w', encoding='utf-8') as cor_file, open('/content/org.txt', 'w', encoding='utf-8') as org_file:
    for file_path in input_files:
        if not os.path.exists(file_path):
            print(f"File not found: {file_path}")
            continue

        with open(file_path, 'r', encoding='utf-8') as f:
            try:
                data = json.load(f)
            except json.JSONDecodeError:
                print(f"Invalid JSON format in file: {file_path}")
                continue

        for item in data:
            prediction = tokanize_and_join(item.get('prediction', '').strip())
            reference = tokanize_and_join(item.get('input', ''))

            if not prediction:
                print(f"Empty prediction at index {item.get('index', 'unknown')} in {file_path}")
                continue

            # Handle multiple references
            if isinstance(reference, list):
                for ref in reference:
                    cor_file.write(prediction + '\n')
                    org_file.write(ref.strip() + '\n')
            elif isinstance(reference, str):
                cor_file.write(prediction + '\n')
                org_file.write(reference.strip() + '\n')
            else:
                print(f"Unexpected reference format at index {item.get('index', 'unknown')} in {file_path}")
                continue
# print("Files hyp.txt and ref.txt generated successfully.")

# %%
# !errant_parallel -orig /content/org.txt -cor /content/cor.txt -out /content/drive/MyDrive/Smruti-GEC-for-Gujarati/hyp5k.m2
# !errant_parallel -orig /content/o.txt -cor /content/c.txt -out /content/ref5k.m2
# !errant_parallel -orig /content/org.txt -cor /content/hyp300.txt -out /content/hyp300.m2
# !errant_parallel -orig /content/org.txt -cor /content/cor_1.txt /content/cor_2.txt /content/cor_3.txt /content/cor_4.txt /content/cor_5.txt /content/cor_6.txt /content/cor_7.txt /content/cor_8.txt /content/cor_9.txt /content/cor_10.txt /content/cor_11.txt -out /content/gold300.m2
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at l3cube-pune/gujarati-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at l3cube-pune/gujarati-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 1 . બાળકો ક્રિકેટનો ખેલ રમી રહ્યા છે
# Loading resources...
# Processing parallel files...
# [('કરવું', 'V_VAUX_VNP'), ('કલ્પી', 'V_VM')] [('માટે', 'PSP'), ('પ્રયત્ન', 'N_NN'), ('કરવું', 'V_VM')]
# [('સોસાઇટી', 'N_NNP')] [('સોસાયટી', 'N_NNP'), ('દ્વારા', 'PSP')]
# [('કયા', 'N_NST')] [('કયો', 'DM_DMQ')]
# [('નહીં', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('ખરું', 'RP_RPD')] [('છ', 'V_VAUX')]
# [('હ', 'V_VAUX')] [('હ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('ક્યોં', 'DM_DMQ')] [('"', 'RD_PUNC'), ('ક્યા', 'N_NST')]
# [('હશ', 'V_VAUX'), ('જ', 'V_VAUX_VNP')] [('જવું', 'V_VM')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('તેનો', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('સ્ત્રી', 'N_NN')] [('સ્ત્રી', 'N_NN'), ('પર', 'PSP')]
# [('પાટે', 'PSP')] [('padding', 'N_NST')]
# [('બનાવાય', 'V_VM')] [('બનાવવામા', 'V_VAUX_VNP'), ('આવવું', 'V_VAUX')]
# [('હ', 'V_VAUX')] [('છ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('કર્ય', 'V_VM')] [('કરવું', 'V_VAUX_VNP')]
# [('?', 'RD_PUNC'), (';', 'RD_PUNC')] [('.', 'RD_PUNC')]
# [('રહ', 'V_VM')] [('રહેલ', 'V_VAUX_VNP')]
# [('હ', 'V_VAUX')] [('હ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('એ', 'PR_PRP')] [('તે', 'DM_DMD')]
# [('ઉઘાડું', 'JJ')] [('ઉઘાડ', 'V_VM')]
# [('દ', 'N_NN'), ('સ્ત્રી', 'N_NN')] [('દીકરીઓ', 'N_NN')]
# [('સરયૂ', 'N_NN')] [('સરયુ', 'JJ')]
# [('આપ્યોઃ', 'V_VM')] [('આપવું', 'V_VM'), (':', 'RD_PUNC')]
# [('ગાવા', 'V_VAUX_VNP'), ('તેની', 'DM_DMD')] [('ગાવાની', 'V_VAUX_VNP')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('રખાવ', 'V_VM'), ('છત', 'N_NN')] [('રાખવું', 'V_VM'), ('છ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('પૂછશેઃ', 'V_VM')] [('પૂછવું', 'V_VM'), (':', 'RD_PUNC')]
# [('બોલીઃ', 'V_VM')] [('બોલવું', 'V_VM'), (':', 'RD_PUNC')]
# [('નહોતા', 'RP_NEG')] [('નહોતું', 'RP_NEG')]
# [('ખાદ્યાન્ન', 'N_NN')] [('ખાદ્ય', 'JJ'), ('અન્ન', 'N_NN')]
# [(':', 'RD_PUNC')] [('છ', 'V_VAUX'), ('?', 'RD_PUNC')]
# [('દેખી', 'V_VM')] [('દેખાવું', 'V_VM'), (',', 'RD_PUNC')]
# [('હ', 'V_VAUX')] [('હશ', 'V_VAUX'), (')', 'RD_SYM'), ('.', 'RD_PUNC')]
# [('પૈઠે', 'PSP')] [('પેઢ', 'N_NN')]
# [('બીક', 'N_NN')] [('કારણે', 'PSP')]
# [('ન', 'RP_NEG'), ('હ', 'V_VAUX')] [('નહોતું', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('તેના', 'DM_DMD')] [('તેનો', 'DM_DMD')]
# [('તેથી', 'PSP')] [('હોવાથી', 'V_VAUX_VNP')]
# [('હ', 'V_VAUX')] [('હોવી', 'V_VAUX_VNP'), ('જોઈએ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('ટાપુ', 'N_NN'), ('જ', 'RP_RPD'), ('ેનિટ્ઝિયો', 'N_NNP')] [('ટાપુ', 'N_NN')]
# [('પૅટ્ઝક્યુઆરોમાં', 'N_NNP')] [('પૅટ્ઝક્યુઆરો', 'N_NNP'), ('.', 'RD_PUNC')]
# [('હોય', 'V_VAUX')] [('છ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('ન', 'RP_NEG'), ('જ', 'RP_RPD'), ('હોય', 'V_VAUX')] [('નથી', 'RP_NEG'), ('હોવ', 'V_VAUX_VNP')]
# [('નવાબસાહેબ', 'N_NNP'), ('પરણવ', 'V_VAUX_VNP')] [('નવાબ', 'N_NN'), ('સાહેબ', 'N_NN'), ('પરણવા', 'JJ')]
# [('આનો', 'DM_DMD')] [('આના', 'DM_DMD')]
# [('તે', 'PSP')] [(',', 'RD_PUNC')]
# [('છ', 'V_VAUX')] [('હ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('શરમાય', 'V_VM'), ('હ', 'V_VAUX')] [('શરમા', 'V_VM'), ('હ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('રાજનીતિ', 'N_NN'), ('ઉભય', 'JJ')] [('રાજનીતિ', 'N_NN')]
# [('નહિ', 'RP_NEG'), ('પણ', 'CC_CCD')] [('નથી', 'RP_NEG'), (',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('સિધાવ', 'V_VM')] [('સિધા', 'V_VM'), ('જાઓ', 'V_VAUX')]
# [('તેનું', 'DM_DMD')] [('તેના', 'DM_DMD')]
# [('તેડ', 'N_NN'), ('કરવા', 'V_VAUX_VNP')] [('તેડવા', 'V_VAUX_VNP')]
# [('જોવી', 'V_VM')] [('જોવ', 'V_VAUX_VNP')]
# [('કરૂંછ', 'V_VM')] [('કરવું', 'V_VM'), ('છ', 'V_VAUX')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('અમે', 'PR_PRP')] [('nuestros', 'RD_RDF')]
# [('ચમક્', 'V_VM'), ('કરવું', 'V_VAUX_VNP'), ('હ', 'V_VAUX')] [('ચમક', 'V_VAUX_VNP'), ('હ', 'V_VAUX')]
# [('ન', 'RP_NEG'), ('છ', 'V_VAUX')] [('નથી', 'RP_NEG')]
# [('ઘણીય', 'QT_QTF'), ('વાર', 'N_NN')] [('ઘણીવાર', 'QT_QTF')]
# [('ઊપર', 'N_NST')] [('ઉપર', 'PSP')]
# [('ન', 'RP_NEG')] [('નહીં', 'RP_NEG'), ('.', 'RD_PUNC')]
# [('કશો', 'DM_DMI')] [('કશું', 'DM_DMI')]
# [('તે', 'PSP')] [('ત્યાર', 'N_NST')]
# [('તે', 'DM_DMD'), ('વખત', 'N_NN'), ('નહોતા', 'RP_NEG')] [('નહોતો', 'RP_NEG')]
# [('થાય', 'V_VM')] [('થાય', 'V_VM'), ('છ', 'V_VAUX')]
# [('પણ', 'RP_RPD')] [('જ', 'RP_RPD')]
# [('નૃત્યગીતવાદ્ય', 'N_NN')] [(',', 'RD_PUNC'), ('નૃત્ય', 'N_NN'), (',', 'RD_PUNC'), ('ગીત', 'N_NN'), (',', 'RD_PUNC'), ('વાદ્ય', 'N_NN')]
# [('મૈ', 'N_NN')] [('મેં', 'PR_PRP')]
# [('જૂ', 'N_NN'), ('નાં', 'RP_NEG')] [('જૂનું', 'JJ')]
# [('કરતું', 'V_VAUX_VNP')] [('કરવું', 'V_VM'), ('છ', 'V_VAUX')]
# [('બનવું', 'V_VM'), ('કરવું', 'V_VAUX_VNP')] [('બનવું', 'V_VAUX_VNP')]
# [('નહીં', 'RP_NEG'), ('હોય', 'V_VAUX')] [('નથી', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('ના', 'RP_NEG')] [('ન', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('ખાતે', 'PSP'), ('છ', 'V_VAUX')] [('છ', 'V_VAUX')]
# [('હ', 'V_VAUX')] [('હશ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('તેવું', 'JJ'), (',', 'RD_PUNC')] [('એવું', 'JJ')]
# [('તેવું', 'JJ')] [('તેમાં', 'DM_DMD')]
# [('નીચું', 'N_NST')] [('હેઠળ', 'PSP')]
# [('અંત', 'N_NN'), (':', 'N_NN'), ('કરણ', 'N_NN')] [('અંતઃકરણ', 'N_NN')]
# [('હ', 'V_VAUX')] [('હ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('ના', 'RP_NEG')] [('ને', 'RP_RPD')]
# [('અનુભવવાની', 'V_VAUX_VNP'), ('ને', 'CC_CCD')] [('અને', 'CC_CCD')]
# [('નમી', 'V_VM')] [('નમીન', 'V_VAUX_VNP')]
# [('આપવુ', 'V_VAUX_VNP'), ('એ', 'PR_PRP')] [('આપવું', 'V_VAUX_VNP'), ('તે', 'DM_DMD'), ('અંગે', 'PSP')]
# [('છેઃ', 'RD_PUNC')] [('છ', 'V_VAUX'), (':', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('એ', 'PR_PRP')] [('તેની', 'DM_DMD')]
# [('માનવું', 'V_VM')] [('માન', 'V_VAUX_VNP')]
# [('ઓપિનિયન', 'N_NNP'), ("'", 'RD_PUNC'), ('ના', 'RP_NEG')] [('ઓપિનિયન', 'N_NNP')]
# [('નવૈ', 'JJ'), ('જીવ', 'N_NN')] [('નવજીવન', 'N_NN')]
# [('ખરું', 'RP_RPD')] [('સાચું', 'JJ'), ('છ', 'V_VAUX')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('લાગિ', 'V_VM')] [('લાગવું', 'V_VAUX')]
# [('રહેવાય', 'V_VM')] [('રહેવા', 'V_VAUX_VNP')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('કઈ', 'DM_DMI')] [('કોઈ', 'DM_DMI')]
# [('માણસ', 'N_NN'), ('તેઓ', 'PR_PRP')] [('માણસ', 'N_NN')]
# [('ઇતિહાસ', 'N_NN'), ('ઘણા', 'QT_QTF'), ('નવું', 'JJ')] [('ઇતિહાસના很多', 'N_NN'), ('નવું', 'JJ')]
# [('કાઢયા', 'V_VAUX')] [('કાઢ્યા', 'V_VAUX'), (',', 'RD_PUNC')]
# [('જવું', 'V_VM')] [('જવા', 'V_VAUX_VNP')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('છ', 'V_VAUX')] [('છ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('જાગૃતાવસ્થા', 'N_NN')] [('જાગૃત', 'JJ'), ('અવસ્થા', 'N_NN')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('જ', 'RP_RPD'), ('ે', 'PSP')] [('જેમ', 'PSP')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('અધિક', 'JJ')] [('વધુ', 'QT_QTF')]
# [('એનો', 'DM_DMD')] [('એ', 'DM_DMD')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('રસાદાર', 'N_NN')] [('રસદાર', 'JJ')]
# [('તેનો', 'DM_DMD')] [('તેના', 'DM_DMD')]
# [('તેનું', 'DM_DMD')] [('તેને', 'DM_DMD')]
# [('ધોઉ', 'V_VM')] [('ધો', 'V_VM'), ('રહેવું', 'V_VAUX')]
# [('જોકે', 'CC_CCS')] [('છતાં', 'RP_RPD')]
# [('રસાદાર', 'N_NN')] [('રસદાર', 'JJ')]
# [('તેનો', 'DM_DMD')] [('તેના', 'DM_DMD')]
# [('તેનું', 'DM_DMD')] [('તેને', 'DM_DMD')]
# [('અનૈ', 'N_NN')] [('છ', 'V_VAUX'), ('અને', 'CC_CCD')]
# [('ધોઉ', 'V_VM')] [('ધો', 'V_VM'), ('રહેવું', 'V_VAUX')]
# [('જોકે', 'CC_CCS')] [('છતાં', 'RP_RPD')]
# [('તે', 'PSP')] [('એ', 'PR_PRP')]
# [('કરેલ', 'V_VAUX_VNP')] [('કરવું', 'V_VM'), ('હ', 'V_VAUX')]
# [('ન', 'RP_NEG'), ('હ', 'V_VAUX')] [('નહોતું', 'RP_NEG')]
# [('ઘર', 'N_NN'), ('પર', 'PSP')] [('ઘર', 'N_NN')]
# [('આકાશ', 'N_NN'), ('ઉપર', 'PSP')] [('આકાશ', 'N_NN')]
# [('સ્કૂલ', 'N_NN'), ('ઉપર', 'PSP')] [('સ્કૂલ', 'N_NN')]
# [('ખિસ્સ', 'N_NN'), ('પર', 'PSP')] [('ખિસ્સા', 'N_NN')]
# [('લાઇબ્રેર', 'N_NN'), ('પર', 'PSP')] [('લાઇબ્રેરી', 'N_NN')]
# [('બગીચ', 'N_NN'), ('ઉપર', 'PSP')] [('બગીચો', 'N_NN')]
# [('ગ્લાસ', 'N_NN'), ('પર', 'PSP')] [('ગ્લાસ', 'N_NN')]
# [('કિતાબ', 'N_NN'), ('ઉપરથી', 'PSP')] [('કિતાબ', 'N_NN')]
# [('ઉતર', 'V_VM')] [('ઉતરી', 'V_VM'), ('ગય', 'V_VAUX')]
# [('ઘર', 'N_NN'), ('પર', 'PSP')] [('ઘેર', 'N_NN')]
# [('છ', 'V_VAUX')] [('છ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('એનાં', 'DM_DMD')] [('એની', 'DM_DMD')]
# [('નહોય', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('તૌ', 'PSP')] [('તોય', 'RP_RPD')]
# [('ના', 'RP_NEG')] [('ન', 'RP_NEG')]
# [('એ', 'PR_PRP')] [('એનું', 'DM_DMD')]
# [('ેવી', 'PSP'), ('જ', 'RP_RPD')] [('છ', 'V_VAUX'), (',', 'RD_PUNC'), ('જે', 'PR_PRL')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('જ', 'RP_RPD')] [('ગય', 'V_VAUX')]
# [('સોશિયાલિસ્ટ', 'JJ')] [('સોશિયલિસ્ટ', 'N_NN')]
# [('હં', 'PSP'), ('ૂફ', 'N_NN')] [('હૂફ', 'N_NN')]
# [('જ', 'RP_RPD')] [('છ', 'V_VAUX')]
# [('માણવાના', 'V_VAUX_VNP'), ('છ', 'V_VAUX')] [('માણવા', 'V_VAUX_VNP'), ('જવું', 'V_VM'), ('રહેવું', 'V_VAUX'), ('છ', 'V_VAUX')]
# [('સહી', 'V_VM')] [('સહન', 'JJ'), ('કરવું', 'V_VM')]
# [('તેમ', 'PSP')] [('એવું', 'JJ')]
# [('અધિક', 'JJ')] [('વધુ', 'QT_QTF')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('નહિ', 'RP_NEG'), ('હોય', 'V_VAUX')] [('નથી', 'RP_NEG')]
# [('મળેન', 'V_VM')] [('મળ', 'V_VM'), ('છ', 'V_VAUX')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('તેનો', 'DM_DMD')] [('એ', 'PR_PRP')]
# [('આવવું', 'V_VM'), ('હશ', 'V_VAUX')] [('આવવું', 'V_VM')]
# [('જ', 'N_NNP'), ('જ', 'N_NNP')] [('અને', 'CC_CCD')]
# [('જ', 'RP_RPD'), ('ેવ', 'JJ')] [('જવ', 'V_VAUX_VNP')]
# [('થોડી', 'QT_QTF')] [('થ', 'V_VAUX_VNP')]
# [('સ્થાપન', 'N_NN')] [('સ્થાપિત', 'JJ')]
# [('ના', 'RP_NEG')] [('ન', 'RP_NEG')]
# [('પણ', 'RP_RPD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('આદરી', 'V_VM')] [('આદરવામા', 'V_VAUX_VNP'), ('આવવું', 'V_VAUX')]
# [('થ', 'V_VM')] [('પહેલ', 'N_NST')]
# [('બલકે', 'PSP')] [('પરંતુ', 'CC_CCD')]
# [('બાપ', 'N_NN')] [('બાપા', 'N_NN'), ('ના', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('દેાડ', 'V_VM')] [('દેવામા', 'V_VAUX_VNP'), ('આવવું', 'V_VAUX')]
# [('દેવું', 'V_VAUX_VNP')] [('દ', 'V_VM'), ('છ', 'V_VAUX')]
# [('ફેંકી', 'V_VM'), ('બાઈનૈ', 'N_NN')] [('બાઈ', 'N_NN')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('એની', 'DM_DMD')] [('એણે', 'PR_PRP')]
# [('એ', 'PR_PRP')] [('એના', 'DM_DMD')]
# [('માલિક', 'N_NN'), ('સાળા', 'N_NN')] [('માલિક', 'N_NN')]
# [('નહિ', 'RP_NEG'), ('જોકે', 'CC_CCS')] [('નથી', 'RP_NEG'), (',', 'RD_PUNC'), ('embora', 'RD_RDF')]
# [('જ', 'RP_RPD'), ('ેવી', 'PSP')] [('જે', 'PR_PRL')]
# [('આપવું', 'V_VM')] [('આપવાની', 'V_VAUX_VNP')]
# [('પિવડાવાય', 'V_VM'), ('હ', 'V_VAUX')] [('પિવડાવા', 'V_VM')]
# [('છ', 'V_VAUX')] [('હોવા', 'V_VAUX_VNP'), ('છતાં', 'RP_RPD')]
# [('સમજાવ્', 'V_VM'), ('કરવું', 'V_VM')] [('સમજાવવું', 'V_VM')]
# [("'", 'RD_PUNC'), ('', 'V_VAUX')] [('હ', 'V_VAUX')]
# [('ઓળંગી', 'V_VAUX_VNP')] [('પસાર', 'JJ'), ('કરવું', 'V_VAUX_VNP')]
# [('ચાંચિ', 'N_NN')] [('ચાંચ', 'N_NN'), ('.', 'RD_PUNC')]
# [(':', 'RD_PUNC')] [('છ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('છ', 'V_VAUX')] [('છ', 'V_VAUX'), (';', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('રાખવું', 'V_VAUX_VNP')] [('રાખવું', 'V_VAUX_VNP'), ('.', 'RD_PUNC')]
# [('છેલ્લું', 'JJ')] [('ગયું', 'V_VAUX'), (',', 'RD_PUNC'), ('છેલ્લું', 'JJ')]
# [('મધુરતાથિ', 'N_NN'), ('એ', 'PR_PRP')] [('મધુરત', 'N_NN'), ('થી', 'PSP'), ('એ', 'PR_PRP')]
# [('કૈ', 'DM_DMI')] [('કે', 'CC_CCS'), ('કઈ', 'DM_DMI')]
# [('શી', 'PR_PRQ')] [('કેવી', 'DM_DMQ')]
# [('કહ્યુંઃ', 'V_VM')] [('કહેવું', 'V_VM'), (':', 'RD_PUNC')]
# [('કેવી', 'DM_DMQ')] [('કઈ', 'DM_DMI')]
# [('દુ', 'N_NN'), (':', 'N_NN'), ('ખ', 'N_NN')] [('દુઃખ', 'N_NN')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('જોકે', 'CC_CCS')] [(',', 'RD_PUNC'), ('embora', 'RD_RDF')]
# [('હ', 'V_VAUX')] [('હ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('ખરું', 'RP_RPD')] [('સાચું', 'JJ'), ('છ', 'V_VAUX')]
# [('ખરું', 'RP_RPD')] [('ખરું', 'RP_RPD')]
# [('કરવું', 'V_VAUX_VNP')] [('કરવું', 'V_VM'), ('રહેવું', 'V_VAUX')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('પૂર્વજોનોએટલ', 'N_NN')] [('પૂર્વજો', 'N_NN'), ('એટલે', 'PSP')]
# [('છત', 'JJ')] [('છ', 'V_VAUX'), ('તો', 'CC_CCD')]
# [('.', 'RD_PUNC')] [('છ', 'V_VAUX')]
# [('ત', 'N_NN')] [('છ', 'V_VAUX')]
# [('મહેક', 'N_NN'), ('થતું', 'V_VAUX_VNP')] [('મહેક', 'V_VAUX_VNP')]
# [('મળવાના', 'V_VAUX_VNP')] [('મળવા', 'V_VAUX_VNP'), ('આવ', 'V_VM')]
# [('જ્યો', 'RP_RPD')] [('જ્યા', 'N_NST')]
# [('મુસલમાન', 'N_NN')] [('musલમાન', 'RD_RDF')]
# [('કુ', 'N_NN'), ('નેહપૂર્વક', 'JJ')] [('કુશળતાપૂર્વક', 'RB')]
# [('તેના', 'DM_DMD')] [(',', 'RD_PUNC'), ('તેને', 'DM_DMD')]
# [('વધવું', 'V_VM'), ('તેમ', 'PSP')] [('વધ', 'V_VAUX_VNP')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('સારુ', 'PSP')] [('માટે', 'PSP'), ('સારું', 'JJ')]
# [('માટે', 'PSP')] [(',', 'RD_PUNC'), ('તેથી', 'PSP')]
# [('!', 'RD_PUNC')] [('માટે', 'PSP')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('જોઇએતેવ', 'JJ')] [('જોઇએ', 'V_VM'), ('તેવું', 'JJ')]
# [('નહિ', 'RP_NEG')] [('નહોતો', 'RP_NEG')]
# [('૧૯ર૭', 'QT_QTC')] [('1977', 'N_NNP')]
# [('૧૯', 'QT_QTO'), ('મી', 'QT_QTO')] [('19મી', 'QT_QTO')]
# [('ગાર્ફિયાસ', 'N_NNP')] [('ગાર્ફિયાસ', 'N_NNP'), ('છ', 'V_VAUX')]
# [('રહ', 'V_VM'), ('લ', 'N_NN')] [('રહેવું', 'V_VAUX_VNP')]
# [("'", 'RD_PUNC')] [('.', 'RD_PUNC'), ('"', 'RD_PUNC')]
# [('કોઇ', 'DM_DMI'), ('કોઇ', 'DM_DMI'), ('વખત', 'N_NN')] [('ક્યારેક', 'N_NST')]
# [('કેઃ', 'CC_CCS')] [('કે', 'CC_CCS'), (':', 'RD_PUNC')]
# [('છ', 'V_VAUX')] [('છ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('૧૯૨', 'QT_QTC'), (':', 'RD_PUNC'), ('', 'N_NST')] [('૧૯૨માં', 'QT_QTC')]
# [('થ', 'V_VM')] [('થ', 'V_VM'), ('.', 'RD_PUNC')]
# [('કૈ', 'V_VM'), ('.', 'RD_PUNC')] [('કે', 'CC_CCS')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('એ', 'PR_PRP')] [('એનું', 'DM_DMD')]
# [('.', 'RD_PUNC'), ('.', 'RD_PUNC'), ('.', 'RD_PUNC')] [('કરવું', 'V_VM')]
# [('હૌ', 'RP_INJ')] [('હ', 'V_VAUX')]
# [('ના', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('પણ', 'CC_CCD')] [('છ', 'V_VAUX'), (',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('તેમાંના', 'DM_DMD'), ('ઘણા', 'QT_QTF')] [('તેમાંના很多', 'DM_DMD')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [(':', 'RD_PUNC')] [('હ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('જ', 'RP_RPD')] [('છ', 'V_VAUX')]
# [('ક્ય', 'N_NST')] [('કયું', 'DM_DMQ')]
# [('જ', 'RP_RPD')] [('છ', 'V_VAUX')]
# [('મેળવ', 'V_VM'), ('હ', 'V_VAUX')] [('મેળવવામા', 'V_VAUX_VNP'), ('આવ્', 'V_VM'), ('હ', 'V_VAUX')]
# [('વાંચ્ય', 'V_VM')] [('વાંચવું', 'V_VAUX_VNP')]
# [('દુન્યવ', 'JJ')] [('દુનિયાવ', 'N_NN')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('ને', 'RP_RPD')] [('છ', 'V_VAUX')]
# [('તેના', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('જ', 'RP_RPD'), ('ેવું', 'PSP')] [('જ્યાર', 'N_NST')]
# [('નાંખ', 'V_VM')] [('નાંખ્', 'V_VM'), ('છ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('હુઆ', 'N_NNP')] [('થ', 'V_VM')]
# [('ઉસ', 'PR_PRP')] [('તેના', 'DM_DMD')]
# [('હમ', 'N_NNP')] [('અમે', 'PR_PRP')]
# [('આયે', 'V_VM')] [('.', 'RD_PUNC')]
# [('તે', 'PSP')] [('તો', 'CC_CCD')]
# [('કહ', 'V_VM')] [('કહેવું', 'V_VAUX_VNP')]
# [('જેવું', 'JJ')] [('જેમના', 'PR_PRL')]
# [('જેવું', 'JJ')] [('જેમના', 'PR_PRL')]
# [('જેવું', 'JJ')] [('જેમના', 'PR_PRL')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('રાત', 'N_NN'), ('અંદર', 'N_NST')] [('રાત', 'N_NN')]
# [('થ', 'V_VM'), ('કરવું', 'V_VM'), ('છ', 'V_VAUX')] [('થાય', 'V_VM'), ('છ', 'V_VAUX')]
# [('જ', 'RP_RPD'), (',', 'RD_PUNC')] [('.', 'RD_PUNC')]
# [('લડાવી', 'V_VM')] [('લડવી', 'V_VAUX_VNP')]
# [('ઉપર', 'PSP')] [('પહેલ', 'N_NST')]
# [('કેવા', 'DM_DMQ')] [('કેવું', 'DM_DMQ')]
# [('કાલાવાલ', 'N_NNP')] [('કાલાવાળ', 'JJ')]
# [('સામો', 'JJ')] [('સામો', 'PSP')]
# [('મોકલી', 'V_VM'), ('આપવુ', 'V_VAUX_VNP')] [('મોકલવા', 'V_VAUX_VNP')]
# [('પણ', 'RP_RPD'), ('છ', 'V_VAUX')] [('છ', 'V_VAUX')]
# [('વિચાર', 'N_NN'), ('થતું', 'V_VAUX_VNP')] [('વિચાર', 'V_VAUX_VNP')]
# [('જોકે', 'CC_CCS')] [('embora', 'RD_RDF')]
# [('ખરું', 'RP_RPD')] [('હ', 'V_VAUX')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('તેથી', 'PSP')] [('તે', 'DM_DMD')]
# [('જૈ', 'N_NN')] [('જો', 'CC_CCD')]
# [('નહોતા', 'RP_NEG')] [('નહોતી', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('જ', 'RP_RPD'), ('ેવા', 'PSP')] [('જેઓ', 'PR_PRL')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('ન', 'RP_NEG'), ('છ', 'V_VAUX')] [('નથી', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('ખાતર', 'PSP')] [('છ', 'V_VAUX')]
# [(',', 'RD_PUNC')] [('થ', 'V_VM')]
# [('થયૌ', 'V_VM')] [('થ', 'V_VM'), ('ગય', 'V_VAUX')]
# [('ખડું', 'JJ')] [('ઊભું', 'V_VM')]
# [('નૈ', 'V_VM')] [('ને', 'CC_CCD')]
# [('ક્રિશ્ચિયનડેમૉક્રૅટિક', 'N_NNP')] [('ક્રિશ્ચિયન', 'N_NNP'), ('ડેમોક્રેટિક', 'N_NNP')]
# [('નહીં', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('શરદ્ઋતુ', 'N_NN')] [('શરદ', 'N_NN'), ('ઋતુ', 'N_NN')]
# [('એ', 'PR_PRP')] [('તેની', 'DM_DMD')]
# [('જ', 'RP_RPD'), ('ેસ્પાર', 'N_NN')] [('જૅસ્પાર', 'N_NN')]
# [('છ', 'V_VAUX'), ('.', 'RD_PUNC')] [('છ', 'V_VAUX')]
# [('બેઠા', 'V_VM')] [('બેઠું', 'V_VM'), ('હ', 'V_VAUX')]
# [('નહોતા', 'RP_NEG')] [('નહોતું', 'RP_NEG')]
# [('થયેલી', 'V_VAUX_VNP')] [('થ', 'V_VM'), ('ગઈ', 'V_VAUX')]
# [('સંબોધી', 'V_VM')] [('સંબોધન', 'N_NN'), ('કરવું', 'V_VM')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('ભુક્ક', 'N_NN')] [('ભુક્ક', 'JJ')]
# [(':', 'RD_PUNC')] [('છ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('નૈ', 'N_NNP')] [('અને', 'CC_CCD')]
# [('કર', 'V_VM')] [('કરવામા', 'V_VAUX_VNP'), ('આવ્યા', 'V_VAUX')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('કર્યોઃ', 'V_VM')] [('કરવું', 'V_VM'), (':', 'RD_PUNC')]
# [('છુટી', 'V_VM'), ('શકવું', 'V_VAUX'), ('એવું', 'JJ'), ('એકે', 'QT_QTC')] [('છૂટવા', 'V_VAUX_VNP'), ('જેવું', 'JJ'), ('એક', 'QT_QTC')]
# [('કરવું', 'V_VAUX_VNP')] [('કરવ', 'V_VAUX_VNP'), (',', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('જ', 'RP_RPD'), ('ેનીઝ', 'N_NNP')] [('જૅનીઝ', 'N_NNP')]
# [('જ', 'RP_RPD'), ('ેનીઝ', 'N_NNP')] [('જૅનીઝ', 'N_NNP')]
# [('ઉપર', 'PSP')] [('પહેલા', 'N_NST')]
# [('તે', 'DM_DMD'), ('વખત', 'N_NN')] [('ત્યાર', 'N_NST')]
# [('ચાળ', 'N_NN'), ('કરવું', 'V_VM')] [('ચાલવું', 'V_VM')]
# [('એની', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('જ', 'RP_RPD'), ('ેવ', 'JJ')] [('જવા', 'V_VAUX_VNP')]
# [('થતું', 'V_VAUX_VNP')] [('થાય', 'V_VM'), ('છ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('તેનો', 'DM_DMD')] [('તેનું', 'DM_DMD')]
# [('જેવું', 'JJ')] [('જેમ', 'PSP')]
# [('તેવાજ', 'JJ')] [('તેમ', 'PSP')]
# [('તેનું', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('લખ', 'V_VAUX_VNP'), ('પણું', 'RP_RPD')] [('પણ', 'RP_RPD')]
# [('પથારિવશ', 'N_NN')] [('પથારી', 'N_NN'), ('વશ', 'N_NN')]
# [('દુ', 'JJ'), (':', 'JJ'), ('ખદ', 'JJ')] [('દુઃખદ', 'JJ')]
# [('અરવિન્દ', 'N_NNP'), ('તે', 'PSP')] [('અરવિન્દ', 'N_NNP')]
# [('નહોતો', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('ભણવું', 'PSP')] [('ભણીન', 'V_VAUX_VNP')]
# [('એને', 'DM_DMD')] [('એ', 'DM_DMD')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('શુંઅર્થાત્', 'PR_PRQ')] [(',', 'RD_PUNC'), ('શું', 'PR_PRQ'), ('અર્થાત્', 'CC_CCD')]
# [('નહોતા', 'RP_NEG')] [('નહોતી', 'RP_NEG')]
# [('જ', 'RP_RPD'), ('', 'N_NNP')] [('જે', 'N_NNP')]
# [('જ', 'RP_RPD'), ('', 'N_NNP')] [('જે', 'N_NNP')]
# [('પુછા', 'V_VM'), ('ગય', 'V_VAUX')] [('પુછા', 'V_VM')]
# [('સ્થાપન', 'N_NN')] [('સ્થાપિત', 'JJ')]
# [('થ', 'V_VAUX_VNP')] [('થાય', 'V_VM'), ('છ', 'V_VAUX')]
# [('કોઈ', 'DM_DMI'), ('કોઈ', 'DM_DMI')] [('કોઈક', 'DM_DMI')]
# [('કાંઇક', 'DM_DMI')] [('કાંઈક', 'DM_DMI')]
# [('તોપણ', 'RP_RPD')] [('તોય', 'RP_RPD')]
# [('૧૯૨', 'QT_QTC'), (':', 'RD_PUNC'), ('', 'N_NN')] [('૧૯૨૦ની', 'QT_QTC')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('કશો', 'DM_DMI')] [('કશું', 'DM_DMI')]
# [('લાંક', 'N_NN')] [('લાંબું', 'JJ')]
# [('અટ', 'N_NST'), ('કાવ', 'N_NN')] [('અટક', 'N_NN')]
# [('હ', 'V_VAUX')] [('હ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('ન', 'RP_NEG'), ('છ', 'V_VAUX')] [('નથી', 'RP_NEG')]
# [('શસ્ત્રાસ્ત્ર', 'N_NN'), ('ધારણ', 'N_NN')] [('શસ્ત્રાધારણ', 'N_NN')]
# [('હત', 'V_VAUX')] [('હ', 'V_VAUX'), (';', 'RD_PUNC')]
# [('છેટ', 'V_VM'), ('છ', 'V_VAUX')] [('છ', 'V_VAUX')]
# [('ગુલાબસિંહ', 'N_NNP'), ('કહ', 'V_VM'), ('હ', 'V_VAUX')] [('ગુલાબસિંહ', 'N_NNP'), ('કહે', 'V_VAUX_VNP')]
# [('આ', 'DM_DMD'), ('તેઓ', 'PR_PRP')] [('આને', 'DM_DMD')]
# [('નહોતા', 'RP_NEG')] [('નહોતું', 'RP_NEG')]
# [('ના', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('કહેવું', 'V_VM'), ('આપવું', 'V_VM')] [('કહ', 'V_VM')]
# [('ખરું', 'RP_RPD')] [('ખરું', 'RP_RPD')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('એના', 'DM_DMD')] [('એનો', 'DM_DMD')]
# [('કેવા', 'DM_DMQ')] [('કેવું', 'DM_DMQ')]
# [('ચોર', 'V_VM')] [('ચોરી', 'N_NN'), ('કરવું', 'V_VM')]
# [('પેટીવીશ', 'N_NNP')] [('પેટ', 'N_NN'), ('વિશે', 'PSP')]
# [('જોઇએએ', 'V_VAUX')] [('જોઈએ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('છ', 'V_VAUX')] [('છ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('કાઠિઆવાડીઅમદાવાદીઓ', 'N_NNP')] [('કાઠિયાવાડી', 'N_NNP'), ('અમદવાદીઓ', 'N_NN')]
# [('બેજ', 'N_NN')] [('બે', 'QT_QTC')]
# [('આવ્યો', 'V_VM')] [('આવ', 'V_VM'), ('હ', 'V_VAUX')]
# [('ગયાન', 'V_VM')] [('ગઈ', 'V_VAUX'), ('હ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('સમર્પ', 'V_VM')] [('સમર્પણ', 'N_NN'), ('કરવું', 'V_VM')]
# [('ઢાંકી', 'V_VM')] [('ઢાંકીન', 'V_VAUX_VNP')]
# [('ગયેલ', 'V_VAUX_VNP')] [('ગ', 'V_VM'), ('.', 'RD_PUNC')]
# [('કરવું', 'V_VAUX_VNP')] [('કરવા', 'V_VAUX_VNP'), ('માટે', 'PSP')]
# [('છ', 'V_VAUX')] [('છ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('છ', 'V_VAUX')] [('છ', 'V_VAUX'), ('કે', 'CC_CCS')]
# [('એમાં', 'DM_DMD'), ('મૃત્યુભય', 'N_NN')] [('એમાં死亡ભય', 'DM_DMD')]
# [('માલીકીસુખ', 'N_NN')] [('માલિકી', 'N_NN'), ('સુખ', 'N_NN')]
# [('હ', 'V_VAUX')] [('હોયશ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('.', 'RD_PUNC'), ('.', 'RD_PUNC')] [(',', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('એક', 'QT_QTC'), ('બીજું', 'JJ')] [('એકબીજાના', 'PR_PRC')]
# [('ધારો', 'V_VM'), ('લ', 'N_NN')] [('માટે', 'PSP')]
# [('અનન્તજીવન', 'N_NN'), ('પરિવર્તો', 'N_NN')] [('અનંત', 'JJ'), ('જીવન', 'N_NN'), ('પરિવર્તન', 'N_NN')]
# [('ભાડે', 'N_NN')] [('ભાડ', 'JJ')]
# [('સ્ફુર', 'N_NN'), ('આવેલી', 'V_VAUX_VNP'), ('ને', 'CC_CCD')] [('સ્ફૂર', 'N_NN'), ('આવવું', 'V_VM'), ('હ', 'V_VAUX'), ('અને', 'CC_CCD')]
# [('લાગવું', 'V_VM'), ('ગય', 'V_VAUX'), ('હ', 'V_VAUX')] [('લાગવું', 'V_VM'), ('હ', 'V_VAUX')]
# [('પહ', 'JJ'), ('લ', 'N_NN')] [('પહેલું', 'QT_QTO')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('તેમ', 'PSP'), ('છ', 'V_VAUX')] [('છ', 'V_VAUX')]
# [('જ', 'V_VAUX_VNP'), ('હ', 'V_VAUX')] [('જ', 'V_VAUX_VNP'), ('હ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('કરાવી', 'V_VM'), ('જાય', 'V_VAUX')] [('કરાવ', 'V_VM')]
# [('વાસ્ત', 'N_NN')] [('માટે', 'PSP')]
# [('"', 'RD_PUNC')] [('છ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('નંદુઃ', 'N_NNP')] [('નંદુ', 'N_NNP'), (':', 'RD_PUNC')]
# [('છૂટ્', 'V_VM'), ('તેની', 'DM_DMD')] [('છ', 'V_VAUX')]
# [('જીવવું', 'V_VAUX_VNP'), ('હ', 'V_VAUX')] [('જીવવું', 'V_VAUX_VNP'), ('હ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('એ', 'PR_PRP')] [('તો', 'RP_RPD')]
# [('છ', 'V_VAUX')] [('જોઈએ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('ગમૈ', 'V_VM')] [('ગમ', 'V_VAUX_VNP')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('ચાલવું', 'V_VM'), ('જ', 'V_VAUX_VNP')] [('ચાલવું', 'V_VAUX_VNP')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('કર્ય', 'V_VAUX_VNP'), ('જાઉ', 'V_VAUX')] [('કરવું', 'V_VM')]
# [("'", 'RD_PUNC')] [('છ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('મે', 'N_NN')] [('મેં', 'PR_PRP'), ('ના', 'RP_NEG')]
# [('સ્ત્રી', 'N_NN'), ('જાતિ', 'N_NN')] [('સ્ત્રીજાતિ', 'N_NN')]
# [('પુરાત', 'N_NN'), ('પડવું', 'V_VM'), ('ગયેલ', 'V_VAUX_VNP')] [('પુરાતન', 'N_NN'), ('પડેલ', 'V_VAUX_VNP')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('કાઈ', 'DM_DMI')] [('કઈ', 'DM_DMI')]
# [('ની', 'RP_RPD')] [('છ', 'V_VAUX')]
# [('અપા', 'V_VM'), ('ગય', 'V_VAUX')] [('અપા', 'V_VM')]
# [('ે', 'PSP'), ('કહ', 'V_VM')] [('કહ', 'V_VM')]
# [('ેવ', 'JJ'), ('જ', 'RP_RPD')] [('માટે', 'PSP')]
# [('મનુષ્યબુદ્ધિ', 'N_NN')] [('મનુષ્ય', 'N_NN'), ('બુદ્ધિ', 'N_NN')]
# [('વધારવ', 'V_VAUX_VNP')] [('વધારવા', 'V_VAUX_VNP'), ('અથવા', 'CC_CCD')]
# [('પણ', 'RP_RPD'), ('થવું', 'V_VAUX_VNP')] [('બનવાન', 'V_VAUX_VNP')]
# [('દુ', 'N_NN'), (':', 'N_NN'), ('ખ', 'N_NN')] [('દુઃખ', 'N_NN')]
# [('છતાંય', 'RP_RPD')] [('છતાં', 'RP_RPD')]
# [('આવૈ', 'V_VM')] [('આવ', 'V_VAUX_VNP')]
# [('પ્રયોજવાના', 'V_VAUX_VNP')] [('પ્રયોજવા', 'V_VAUX_VNP'), ('માટે', 'PSP')]
# [('છેઃ', 'RD_PUNC')] [('છ', 'V_VAUX'), (':', 'RD_PUNC')]
# [('જેવું', 'JJ')] [('જેમ', 'PSP')]
# [('શહેર', 'N_NN'), ('તેને', 'DM_DMD')] [('શહેર', 'N_NN')]
# [('વાસ્ત', 'N_NN')] [('માટે', 'PSP')]
# [('છ', 'V_VAUX')] [('છ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('તેનું', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('ગી', 'V_VM')] [('.', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('તેવું', 'JJ')] [('તેમાં', 'DM_DMD')]
# [('વિને', 'RP_RPD')] [('વિના', 'PSP')]
# [('નહિ', 'RP_NEG'), ('પણ', 'RP_RPD')] [('નહીં', 'RP_NEG'), (',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('જોઇએએવીજ', 'V_VAUX')] [('જોઈએ', 'V_VAUX'), ('એવીજ', 'JJ')]
# [('કરેલું', 'V_VAUX_VNP')] [('કરવું', 'V_VM'), ('હ', 'V_VAUX')]
# [('મળ', 'V_VM'), ('તેમ', 'PSP'), ('નહોતું', 'RP_NEG')] [('મળ', 'V_VAUX_VNP'), ('નહોતી', 'RP_NEG')]
# [('તેનાં', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('એક્કે', 'QT_QTC')] [('એક', 'QT_QTC'), ('જ', 'RP_RPD')]
# [('તે', 'DM_DMD'), ('વખત', 'N_NN')] [('ત્યાર', 'N_NST')]
# [('એક', 'QT_QTC'), ('સમગ્ર', 'JJ')] [('એક整体ના', 'QT_QTC')]
# [('ક', 'V_VM')] [("'ક્યાં", 'RD_PUNC')]
# [('', 'N_NN'), ('.', 'RD_PUNC'), ('', 'N_NN')] [('એ', 'PR_PRP')]
# [('તેમાંનો', 'DM_DMD')] [('તેમાં', 'DM_DMD')]
# [('એના', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('ક્હ', 'V_VM'), ('હ', 'V_VAUX')] [('કેહ', 'V_VAUX_VNP')]
# [('એક', 'QT_QTC'), ('બીજાં', 'JJ')] [('એકબીજાના', 'PR_PRC')]
# [('છ', 'V_VAUX')] [('હ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('મુદ્દત', 'N_NN')] [('müddત', 'RD_RDF')]
# [('કરવું', 'V_VM'), ('હ', 'V_VAUX')] [('કરવું', 'V_VM')]
# [('દે', 'V_VM')] [('દેવું', 'V_VAUX_VNP')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('તેઓ', 'PR_PRP'), ('ને', 'CC_CCD')] [('તેઓ', 'PR_PRP')]
# [('પરિણતિ', 'N_NN')] [('परिणતિ', 'RD_RDF')]
# [('ઘટ', 'V_VM')] [('જોઈએ', 'V_VAUX')]
# [('કાંઇ', 'DM_DMI'), ('ખાવાબાવાની', 'V_VAUX_VNP'), ('ભાનસાન', 'N_NN')] [('કાંઈ', 'DM_DMI'), ('ખાવા', 'V_VAUX_VNP'), ('બાવા', 'N_NN'), ('ભાનસાંજ', 'N_NN')]
# [('ઉભું', 'JJ')] [('ઊભું', 'V_VM')]
# [('ન', 'RP_NEG'), ('હ', 'V_VAUX')] [('નહોતો', 'RP_NEG')]
# [('નીચું', 'N_NST')] [('હેઠળ', 'PSP')]
# [('સબજજ', 'JJ')] [('સબજેક્ટ', 'N_NN')]
# [('કંઈ', 'DM_DMI')] [('કઈ', 'DM_DMI')]
# [('તેનું', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('કાઈ', 'DM_DMI')] [('કઈ', 'DM_DMI')]
# [('થ', 'V_VAUX_VNP')] [('થાય', 'V_VM'), ('છ', 'V_VAUX')]
# [('ઊચ્ચ', 'N_NST')] [('ઊંચું', 'JJ')]
# [('ભાઈસ', 'N_NN'), ("'", 'RD_PUNC'), ('બ', 'N_NN')] [('ભાઈસાહેબ', 'N_NN')]
# [('અનેમાં', 'CC_CCD'), ('સરજુ', 'V_VM')] [('અને', 'CC_CCD'), ('તેમાં', 'DM_DMD'), ('સર', 'V_VM')]
# [('કંઈ', 'DM_DMI'), ('કંઈ', 'DM_DMI')] [('કંઈક', 'DM_DMI')]
# [('રહીનહી', 'V_VM')] [('રહેવું', 'V_VM'), ('નથી', 'RP_NEG')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('વીનવ', 'V_VM')] [('વિનંતી', 'N_NN'), ('કરવું', 'V_VM'), ('.', 'RD_PUNC')]
# [('આવ્', 'V_VM'), ('કરવું', 'V_VM')] [('આવવું', 'V_VM')]
# [('શિખવાથીજ', 'V_VAUX_VNP')] [('શીખવાથી', 'V_VAUX_VNP'), ('જ', 'RP_RPD')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('તેનો', 'DM_DMD')] [('તેને', 'DM_DMD')]
# [('ઉઘાડું', 'JJ'), ('કરવું', 'V_VAUX_VNP')] [('ઉઘાડીન', 'V_VAUX_VNP')]
# [('હ', 'V_VAUX'), ('કે', 'CC_CCS'), ('નહિ', 'RP_NEG')] [('નહોતું', 'RP_NEG')]
# [('તેમાં', 'DM_DMD')] [('તેઓ', 'PR_PRP')]
# [('સિંહાસ', 'N_NN')] [('સિંહાસન', 'N_NN'), ('પર', 'PSP')]
# [('મળનિ', 'N_NN'), (':', 'RD_PUNC')] [('મળનારા', 'V_VAUX_VNP')]
# [('બનવું', 'V_VM'), ('ગયું', 'V_VAUX_VNP')] [('બનવું', 'V_VAUX_VNP')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('હૌય', 'RP_RPD')] [('હો', 'V_VAUX')]
# [('તેની', 'DM_DMD')] [('તે', 'DM_DMD'), ('અંગે', 'PSP')]
# [('તેનો', 'DM_DMD')] [('એ', 'PR_PRP')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('એઓ', 'DM_DMD')] [('એ', 'DM_DMD')]
# [('નહિ', 'RP_NEG'), ('હોય', 'V_VAUX')] [('નથી', 'RP_NEG')]
# [('ઓળંગી', 'V_VM')] [('પસાર', 'JJ'), ('કરવું', 'V_VAUX_VNP')]
# [('તેનું', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('અંદર', 'JJ')] [('અંદર', 'N_NST')]
# [('જ', 'RP_RPD'), ('ેનાથી', 'V_VAUX_VNP')] [('જેણાથી', 'PR_PRL')]
# [('ટબ', 'N_NN')] [('.', 'RD_PUNC')]
# [('તેનાં', 'DM_DMD')] [('છ', 'V_VAUX'), ('એ', 'PR_PRP')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('ખરું', 'RP_RPD')] [('છ', 'V_VAUX')]
# [('પણ', 'RP_RPD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('કહ', 'V_VM')] [('કહેવું', 'V_VAUX_VNP')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('વાલ', 'N_NN')] [('વાળા', 'PSP')]
# [('ઢીલેવીલ', 'JJ')] [('ઢીલ', 'JJ'), ('વીલ', 'JJ')]
# [('માનવું', 'V_VM'), ('લેવામા', 'V_VAUX_VNP')] [('માનવામા', 'V_VAUX_VNP')]
# [('હ', 'V_VAUX'), ('.', 'RD_PUNC')] [('હ', 'V_VAUX')]
# [('નહિ', 'RP_NEG'), ('હોય', 'V_VAUX')] [('નથી', 'RP_NEG')]
# [('હેઠ', 'PSP')] [('હું', 'PR_PRP')]
# [("'", 'RD_PUNC')] [('છ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('બોલીઃ', 'V_VM')] [('બોલવું', 'V_VM'), (':', 'RD_PUNC'), ('"', 'RD_PUNC')]
# [('નહીં', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('ના', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('કળવ', 'JJ')] [('સમજવ', 'V_VAUX_VNP')]
# [('તેથી', 'PSP')] [('હોવાથી', 'V_VAUX_VNP')]
# [('તે', 'DM_DMD')] [('ત્યાર', 'N_NST')]
# [('જોઈ', 'V_VAUX_VNP'), ('હોય', 'V_VAUX')] [('જોઈએ', 'V_VM')]
# [('છેજ', 'V_VM'), ('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('જ', 'RP_RPD'), ('ેને', 'PSP')] [('જેની', 'PR_PRL')]
# [('ઊભ', 'V_VAUX_VNP')] [('ઊભું', 'JJ'), ('થ', 'V_VM')]
# [('રાખવું', 'V_VM')] [('માન્ય', 'JJ')]
# [('માન્ય', 'JJ')] [('રાખવું', 'V_VM')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('દુ', 'N_NN'), (':', 'N_NN'), ('ખ', 'N_NN')] [('દુઃખ', 'N_NN')]
# [(':', 'RD_PUNC')] [('.', 'RD_PUNC'), ('હિ', 'N_NNP'), ('.', 'RD_PUNC')]
# [('?', 'RD_PUNC')] [('હ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('અગર', 'PSP')] [('અને', 'CC_CCD')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('હેઠથી', 'PSP')] [('ઢીથી', 'RB')]
# [('છાનામા', 'JJ')] [('છાના', 'N_NN')]
# [('કરેલ', 'V_VAUX_VNP')] [('કરવું', 'V_VM'), ('હ', 'V_VAUX')]
# [('ન', 'RP_NEG'), ('છ', 'V_VAUX')] [('નથી', 'RP_NEG')]
# [('પ્રતિકાર', 'N_NN'), ('રુપ', 'N_NN')] [('પ્રતિકારરૂપ', 'N_NN')]
# [('છ', 'V_VAUX')] [('છ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('જોકે', 'CC_CCS')] [('embora', 'RD_RDF')]
# [(',', 'RD_PUNC'), ('ને', 'CC_CCD')] [('અને', 'CC_CCD')]
# [('ખેડૂતસાહુકાર', 'N_NN')] [('ખેડૂત', 'N_NN'), ('અને', 'CC_CCD'), ('સાહુકાર', 'N_NN')]
# [('જૌ', 'V_VM')] [('જાઉ', 'V_VAUX'), ('છ', 'V_VAUX')]
# [('દીધેલ', 'V_VAUX_VNP')] [('દ્વારા', 'PSP'), ('આપવામા', 'V_VAUX_VNP'), ('આવેલ', 'V_VAUX_VNP')]
# [('પાંચસોએક', 'QT_QTC')] [('પાંચસોય', 'QT_QTC'), ('એક', 'QT_QTC')]
# [('નીચું', 'N_NST')] [('હેઠળ', 'PSP')]
# [('ફ', 'N_NN')] [('ફેલા', 'V_VM'), ('છ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('એકનું', 'QT_QTC'), ('એક', 'QT_QTC')] [('એકમાત્ર', 'PSP')]
# [('પડવું', 'N_NN'), ('પીવ', 'V_VAUX_VNP')] [('પીવ', 'V_VAUX_VNP'), ('પડવું', 'V_VAUX'), ('છ', 'V_VAUX')]
# [('આપવાઃ', 'V_VAUX_VNP')] [('આપવા', 'V_VAUX_VNP'), (':', 'RD_PUNC')]
# [('ક્વચિત્', 'RB')] [('ક્વચિત', 'JJ')]
# [('ક્વચિત્', 'RB')] [('ક્વચિત', 'JJ')]
# [('નહોતું', 'RP_NEG')] [('નહોતી', 'RP_NEG')]
# [('છેચાવી', 'V_VM')] [('છ', 'V_VAUX'), (',', 'RD_PUNC'), ('ચાવી', 'V_VAUX_VNP')]
# [('ેવ', 'JJ'), ('હ', 'V_VAUX')] [('હ', 'V_VAUX')]
# [('એય', 'RP_RPD')] [('એ', 'DM_DMD')]
# [('કર', 'V_VM')] [('કરવામા', 'V_VAUX_VNP'), ('આવ્યા', 'V_VAUX')]
# [('નહોતા', 'RP_NEG')] [('નહોતો', 'RP_NEG')]
# [('થયોએમ', 'V_VM')] [('થયોએ', 'V_VM'), ('એમ', 'PSP')]
# [('હ', 'V_VAUX')] [('હ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('લૈત', 'N_NN')] [('લેવું', 'V_VAUX_VNP')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('જ', 'RP_RPD')] [('છ', 'V_VAUX')]
# [('ઓળંગી', 'V_VM')] [('પસાર', 'JJ'), ('કરવું', 'V_VAUX_VNP')]
# [('ના', 'RP_NEG')] [('ન', 'RP_NEG')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('દૂ', 'N_NN'), (':', 'N_NN'), ('ખ', 'N_NN')] [('દુઃખ', 'N_NN')]
# [('તેમની', 'DM_DMD')] [('તેમના', 'DM_DMD')]
# [('ઝબકબ', 'N_NNP')] [('ઝબકબા', 'N_NNP'), ('છ', 'V_VAUX')]
# [(',', 'RD_PUNC')] [('હોવા', 'V_VAUX_VNP')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('થવાના', 'V_VAUX_VNP'), ('જ', 'RP_RPD')] [('થવાની', 'V_VAUX_VNP')]
# [('જ', 'RP_RPD'), ('ૈ', 'N_NN')] [('જે', 'PR_PRL')]
# [('હવે', 'N_NST')] [('"', 'RD_PUNC'), ('હવે', 'N_NST')]
# [('ચાલવું', 'V_VM')] [('રહેવું', 'V_VAUX')]
# [('નજીવું', 'JJ')] [('negligible', 'RD_RDF')]
# [('વિચાર', 'N_NN'), ('ન', 'RP_NEG')] [('વિચાર', 'N_NN')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('મોકલીય', 'V_VM')] [('મોકલ્', 'V_VM'), ('છ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('સાહેબ', 'N_NN'), ('છો', 'N_NN')] [('સાહેબ', 'N_NN')]
# [('નહિ', 'RP_NEG'), ('પણ', 'CC_CCD')] [('નથી', 'RP_NEG'), (',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('નહિ', 'RP_NEG'), ('હોય', 'V_VAUX')] [('નથી', 'RP_NEG')]
# [('જ', 'RP_RPD'), ('અહીં', 'N_NST')] [('છ', 'V_VAUX'), (',', 'RD_PUNC'), ('જે', 'PR_PRL'), ('અહી', 'N_NST')]
# [('મળેલા', 'V_VAUX_VNP'), ('કન્યાદાન', 'N_NN'), ('ને', 'CC_CCD')] [('મળેલા', 'V_VAUX_VNP'), ('કન્યાદાન', 'N_NN')]
# [('રાખિ', 'V_VM')] [('રાખી', 'V_VM'), (',', 'RD_PUNC')]
# [('એના', 'DM_DMD')] [('એનો', 'DM_DMD')]
# [('હૌવા', 'N_NN')] [('હોવાન', 'V_VAUX_VNP'), ('કારણે', 'PSP')]
# [('પ્લૅટફોર્મ', 'N_NN'), ('ઓળંગવા', 'V_VAUX_VNP')] [('પ્લેટફોર્મ', 'N_NN'), ('પસાર', 'JJ'), ('કરવા', 'V_VAUX_VNP')]
# [('તેમ', 'PSP')] [('ત્યાર', 'N_NST')]
# [('અદભુત', 'JJ'), ('જ', 'RP_RPD'), ('ેટ', 'N_NN')] [('અદભૂત', 'JJ'), ('જેટ', 'N_NN')]
# [('પહોંચી', 'V_VM'), ('જવાન', 'V_VAUX_VNP')] [('પહોંચવાન', 'V_VAUX_VNP')]
# [('સૂર્ય', 'N_NN'), ('ક', 'N_NNP')] [('સૂર્ય', 'N_NN')]
# [('કિરણ', 'N_NNP'), ('સે', 'PSP'), ('સૂર્ય', 'N_NN'), ('ક', 'N_NNP')] [('કિરણ', 'N_NN'), ('સૂર્ય', 'N_NN')]
# [('તક', 'N_NNP')] [('સુધી', 'PSP')]
# [('ફ્લૅટ', 'N_NN')] [('ફ્લેટ', 'JJ')]
# [('નહિ', 'RP_NEG')] [('ન', 'RP_NEG')]
# [('પ્રોફ', 'N_NN'), ('શનલ', 'N_NN'), ('મૅનેજમેન્ટ', 'N_NNP')] [('પ્રોફેશનલ', 'N_NN'), ('મેનેજમેન્ટ', 'N_NN')]
# [('આવવું', 'V_VM')] [('આવવું', 'V_VM'), ('છ', 'V_VAUX')]
# [('હાય', 'PSP')] [('હોય', 'V_VAUX')]
# [('હતોઅલબત્ત', 'V_VAUX')] [('હ', 'V_VAUX'), (';', 'RD_PUNC'), ('અલબત્ત', 'PSP')]
# [('ન', 'RP_NEG'), ('રહ', 'V_VAUX')] [('નથી', 'RP_NEG')]
# [('તેના', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('હ', 'V_VAUX')] [('છ', 'V_VAUX'), (';', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('એ', 'PR_PRP')] [('એ', 'DM_DMD')]
# [('માધેવ', 'N_NN')] [('માધવ', 'N_NNP'), (',', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('તેનું', 'DM_DMD')] [('તેના', 'DM_DMD')]
# [('ફે', 'V_VM'), ('દવા', 'N_NN')] [('ફેંકવા', 'V_VAUX_VNP')]
# [('જ', 'RP_RPD'), ('ેવ', 'JJ')] [('જેઓ', 'PR_PRL')]
# [('ટબ', 'N_NN')] [('.', 'RD_PUNC')]
# [('હ', 'V_VAUX')] [('હ', 'V_VAUX'), (';', 'RD_PUNC')]
# [('નહોતાં', 'RP_NEG')] [('નહોતું', 'RP_NEG')]
# [('રહેવું', 'V_VM'), ('ગય', 'V_VAUX')] [('રહેવું', 'V_VAUX')]
# [('કયી', 'DM_DMQ')] [('કઈ', 'DM_DMI')]
# [('તેનો', 'DM_DMD')] [('તેના', 'DM_DMD')]
# [('સુભગ', 'JJ')] [('સુભાગ', 'N_NN')]
# [('તેનું', 'DM_DMD')] [('તેના', 'DM_DMD')]
# [('હ', 'V_VAUX')] [('હ', 'V_VAUX'), ('કે', 'CC_CCS')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('જ', 'RP_RPD'), ('ેમ', 'N_NN')] [('જેમાં', 'PR_PRL')]
# [('મૉડલ', 'N_NN')] [('મોડલ', 'N_NN'), ('છ', 'V_VAUX')]
# [('હું', 'PR_PRP')] [(',', 'RD_PUNC'), ('હું', 'PR_PRP')]
# [('બીજ', 'N_NN'), ('', 'N_NN'), ('દિ', 'N_NN')] [('બીજું', 'JJ'), ('દિવસ', 'N_NN')]
# [('સોનુ', 'N_NN')] [('સોનું', 'JJ')]
# [('છેલ્લું', 'JJ')] [('últimos', 'RD_RDF')]
# [('સારું', 'V_VM')] [('સારું', 'JJ')]
# [('દેખી', 'V_VM')] [('જોઈ', 'V_VAUX_VNP')]
# [('તેના', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('ઓચિંતું', 'JJ')] [('ઓચિંતામાં', 'RB')]
# [('પી', 'V_VM'), ('જવ', 'V_VAUX_VNP')] [('પીવા', 'V_VM')]
# [('નહીં', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('મા', 'V_VM')] [('માન', 'V_VAUX_VNP')]
# [('એ', 'PR_PRP')] [('તેના', 'DM_DMD')]
# [('વિયેનાનગર', 'N_NNP')] [('વિયે', 'N_NNP'), ('નગર', 'N_NNP')]
# [('ના', 'RP_NEG')] [('ન', 'RP_NEG'), ('હ', 'V_VAUX')]
# [('નીચું', 'N_NST')] [('હેઠળ', 'PSP')]
# [('જિવ', 'N_NN'), ('ખાય', 'V_VM')] [('જીવ', 'N_NN'), ('ખા', 'V_VM'), ('રહેવું', 'V_VAUX')]
# [('એકલું', 'JJ'), ('ઉભ', 'JJ')] [('એકલું', 'JJ')]
# [('એકાદ', 'JJ')] [('એક', 'QT_QTC')]
# [('સર્જાયલ', 'V_VAUX_VNP')] [('માટે', 'PSP'), ('સર્જાયેલ', 'V_VAUX_VNP')]
# [('કરવું', 'V_VM'), ('અંહીયા', 'N_NST')] [('કરવું', 'V_VM'), (';', 'RD_PUNC'), ('અહિંયા', 'N_NST')]
# [('નહોતું', 'RP_NEG')] [('નહોતી', 'RP_NEG')]
# [('માનવું', 'V_VM'), ('શકવું', 'V_VAUX')] [('માનવામા', 'V_VAUX_VNP'), ('આવવું', 'V_VAUX'), ('છ', 'V_VAUX')]
# [('પડ', 'V_VM')] [('પડવું', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('તેને', 'DM_DMD'), ('સારુ', 'PSP')] [('સારું', 'JJ')]
# [('તેએાની', 'DM_DMD')] [('તે', 'DM_DMD'), ('એ', 'PR_PRP')]
# [('તેનો', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('હ', 'V_VAUX')] [('હ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('તેના', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('નહીં', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('ધીમેથી', 'RB'), ('ચાલવું', 'V_VAUX_VNP')] [('ધીમે', 'RB'), ('ધીમે', 'RB'), ('ચાલવું', 'V_VAUX_VNP')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('ફ', 'N_NN'), ('ૂકા', 'V_VM')] [('ફૂકા', 'V_VM')]
# [('કંઈ', 'DM_DMI'), ('કંઈ', 'DM_DMI')] [('કંઈક', 'DM_DMI')]
# [('માનવું', 'V_VM')] [('માન', 'V_VAUX_VNP')]
# [('જ', 'RP_RPD'), ('ે', 'N_NN')] [('છેમા', 'V_VAUX')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('તેટલૌ', 'JJ')] [(',', 'RD_PUNC'), ('તેટલા', 'JJ')]
# [('તેથી', 'PSP')] [('હોવાથી', 'V_VAUX_VNP')]
# [('જોયેલ', 'V_VAUX_VNP')] [('જો', 'V_VM'), ('હ', 'V_VAUX')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('ક્યે', 'PR_PRQ'), ('વખત', 'N_NN')] [('ક્યાર', 'N_NST')]
# [('સારૂં', 'PSP')] [('સારું', 'JJ'), (',', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('કેવડો', 'DM_DMQ')] [('કેવો', 'DM_DMQ')]
# [('તેવુ', 'JJ')] [('તે', 'DM_DMD')]
# [('પીળીપ્રતિષ્ટિ', 'N_NN')] [('પીળું', 'JJ'), ('પ્રતિષ્ઠા', 'N_NN')]
# [('ખડું', 'JJ')] [('ઊભું', 'V_VM')]
# [('એનું', 'DM_DMD')] [('તેનું', 'DM_DMD')]
# [('ઉપર', 'PSP'), ('જગા', 'N_NN')] [('જગ્યા', 'N_NN')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('વહ', 'V_VM')] [('વહે', 'V_VAUX_VNP')]
# [('એઓ', 'DM_DMD')] [('એ', 'DM_DMD')]
# [('આપવું', 'V_VM'), ('હ', 'V_VAUX')] [('આપવું', 'V_VM')]
# [('એઓ', 'DM_DMD')] [('એમાં', 'DM_DMD')]
# [('ઉભય', 'N_NN')] [('બંને', 'JJ')]
# [('તેનો', 'DM_DMD')] [('તેના', 'DM_DMD')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('તેને', 'DM_DMD')] [('તે', 'DM_DMD')]
# [('માશ', 'N_NN')] [('સાથે', 'PSP')]
# [('તે', 'DM_DMD'), ('વખત', 'N_NN')] [('ત્યાર', 'N_NST')]
# [('ઘટ્ટ', 'JJ')] [('ઘાટ', 'N_NN')]
# [('ઠંડુંગાર', 'N_NN')] [('ઠંડું', 'JJ')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('ક્ય', 'N_NST')] [('કયું', 'DM_DMQ')]
# [('બોલાવી', 'V_VM')] [('બોલાવીન', 'V_VAUX_VNP')]
# [('બેસિ', 'V_VM')] [(',', 'RD_PUNC'), ('બેસી', 'V_VM')]
# [('કરવું', 'V_VM')] [('કરવું', 'V_VAUX_VNP')]
# [('માટે', 'PSP'), ('છ', 'V_VAUX')] [('છ', 'V_VAUX')]
# [('કરવું', 'V_VM')] [('કરવું', 'V_VM'), ('રહેવું', 'V_VAUX')]
# [('કાદવ', 'N_NN'), ('તેમાં', 'DM_DMD')] [('કાદવ', 'N_NN')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('ખાવ', 'V_VM')] [('ખાવા', 'V_VAUX_VNP')]
# [('ભાઈઓય', 'N_NN')] [('ભાઈ', 'N_NN'), (',', 'RD_PUNC')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('છ', 'V_VAUX'), ('રહેવાના', 'V_VAUX_VNP')] [('રહેવું', 'V_VAUX'), ('છ', 'V_VAUX'), ('રહેવા', 'V_VAUX_VNP'), ('માટે', 'PSP')]
# [('વળ', 'V_VAUX_VNP'), ('વર્ષ', 'N_NN')] [('વળતી年的', 'V_VAUX_VNP')]
# [('ચાલવું', 'V_VM')] [('ચાલવું', 'V_VAUX_VNP')]
# [('ખરીદ', 'N_NN'), ('કરવું', 'V_VM')] [('ખરીદવું', 'V_VM')]
# [('હ', 'V_VAUX')] [('હ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નહોતી', 'RP_NEG')]
# [('જતોઃ', 'V_VAUX_VNP')] [('જ', 'V_VAUX_VNP'), (':', 'RD_PUNC')]
# [('નહીં', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('જોઈ', 'V_VAUX_VNP'), ('હોય', 'V_VAUX')] [('જોઈએ', 'V_VM')]
# [('કરવું', 'V_VAUX_VNP')] [('કરવું', 'V_VM'), ('છ', 'V_VAUX')]
# [('જ', 'RP_RPD')] [('હ', 'V_VAUX')]
# [('ચૂંટણી', 'N_NN'), ('થ', 'V_VM'), ('તે', 'DM_DMD'), ('તમામ', 'JJ')] [('ચૂંટણી', 'N_NN')]
# [('બવ', 'N_NN')] [('બહુ', 'QT_QTF')]
# [('તૂટી', 'V_VM'), ('જવું', 'V_VAUX')] [('તૂટ', 'V_VM')]
# [('કેઃ', 'CC_CCS')] [('કે', 'CC_CCS'), (':', 'RD_PUNC')]
# [('તેમજ', 'CC_CCD')] [('તેમ', 'PSP')]
# [('શિખ', 'N_NN')] [('શીખ', 'V_VM')]
# [('જેનુ', 'PR_PRL'), ('છ', 'V_VAUX'), ('એ', 'PR_PRL'), ('જ', 'RP_RPD')] [('જેની', 'PR_PRL')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG'), (',', 'RD_PUNC')]
# [('ેમ', 'PSP')] [('હું', 'PR_PRP')]
# [('રાખ', 'V_VM')] [('રાખી', 'V_VM'), ('રહેવું', 'V_VAUX')]
# [('દોરા', 'N_NN')] [('દોરવાન', 'V_VAUX_VNP')]
# [('આવડવ', 'V_VM')] [('આવડવ', 'V_VAUX_VNP')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('તમરા', 'N_NN')] [('તમે', 'PR_PRP')]
# [('ખડ', 'JJ')] [('ઊભું', 'V_VM')]
# [('સાંભળ્', 'V_VM'), ('કરવું', 'V_VM')] [('સાંભળવું', 'V_VM')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('થ', 'V_VM')] [('હશ', 'V_VAUX')]
# [('જાવ', 'V_VAUX')] [('જાઓ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('માંડ્યા', 'V_VAUX')] [('શરૂ', 'JJ'), ('કરવું', 'V_VM')]
# [('છેલ્લું', 'JJ')] [('últimos', 'RD_RDF')]
# [("'", 'RD_PUNC'), ('', 'V_VAUX')] [('છ', 'V_VAUX')]
# [('રમવું', 'V_VAUX_VNP')] [(',', 'RD_PUNC'), ('રમ', 'V_VAUX_VNP')]
# [('ને', 'CC_CCD'), ('ખાતાંપી', 'V_VAUX_VNP')] [('અને', 'CC_CCD'), ('ખા', 'V_VAUX_VNP'), ('પી', 'V_VAUX_VNP')]
# [('પણ', 'RP_RPD')] [('છ', 'V_VAUX'), (',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('તેમ', 'PSP'), ('હોય', 'V_VAUX')] [('છ', 'V_VAUX')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('નહોતાં', 'RP_NEG')] [('નહોતી', 'RP_NEG'), ('.', 'RD_PUNC')]
# [('દુ', 'N_NN'), (':', 'N_NN'), ('ખાગ્નિ', 'N_NN')] [('દુઃખાગ્નિ', 'N_NN')]
# [('?', 'RD_PUNC'), ('ઠીકબહેન', 'PSP')] [('"', 'RD_PUNC'), ('ઠીક', 'PSP'), (',', 'RD_PUNC'), ('બહેન', 'N_NN')]
# [('એમાંથી', 'DM_DMD'), ('ઘણા', 'QT_QTF')] [('એમાંથી很多', 'DM_DMD')]
# [('કરવું', 'V_VAUX_VNP'), ('કે', 'CC_CCS'), ('આબરૂ', 'N_NN'), ('કર', 'V_VAUX_VNP')] [('કર', 'V_VAUX_VNP'), ('આબરૂ', 'N_NN')]
# [('કરવાનુ', 'V_VAUX_VNP')] [('કરવા', 'V_VAUX_VNP'), ('માટે', 'PSP')]
# [('બનવું', 'V_VM'), ('રહેવું', 'V_VAUX'), ('હ', 'V_VAUX')] [('બનવું', 'V_VAUX_VNP'), ('હ', 'V_VAUX')]
# [('થઇશઃ', 'V_VM')] [('થઇ', 'V_VM'), (':', 'RD_PUNC')]
# [('કર', 'N_NN'), ('કરવું', 'V_VAUX_VNP')] [('કરાવી', 'V_VM')]
# [('જ', 'RP_RPD'), ('ે', 'N_NN')] [('જેમા', 'PR_PRL')]
# [('આ', 'N_NN')] [('આણા', 'V_VM')]
# [('પણ', 'CC_CCD')] [('છ', 'V_VAUX'), (',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('પણ', 'RP_RPD')] [('પછી', 'PSP'), (',', 'RD_PUNC')]
# [('અગર', 'PSP')] [('અને', 'CC_CCD')]
# [('દુ', 'N_NN'), ('?', 'N_NN'), ('ખ', 'N_NN')] [('દુઃખ', 'N_NN')]
# [('પાત્રનૈ', 'N_NN'), ('આજ', 'N_NST'), ('', 'N_NN')] [('પાત્ર', 'N_NN'), ('આજ', 'N_NST')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('દે', 'V_VM')] [('દેવામા', 'V_VAUX_VNP')]
# [('તેનાં', 'DM_DMD')] [('તેની', 'DM_DMD')]
# [('ક્ય', 'N_NST')] [('કઈ', 'DM_DMI')]
# [('ભરન', 'N_NN'), ('ગઈ', 'N_NST')] [('ભરવા', 'V_VAUX_VNP'), ('ગઈ', 'V_VM'), ('હ', 'V_VAUX')]
# [('ક્યું', 'DM_DMQ')] [('ક્ય', 'N_NST')]
# [('માટે', 'PSP')] [('કે', 'CC_CCS')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('સિપાઈ', 'N_NN'), ('માંદુ', 'N_NN')] [('સિપાઈઓ', 'N_NN')]
# [('જાણેકે', 'PSP')] [('જાણીન', 'V_VAUX_VNP')]
# [('તેનો', 'DM_DMD')] [('એ', 'PR_PRP')]
# [('એ', 'PR_PRP')] [('ત્યાર', 'N_NST')]
# [('ઉતારુઓ', 'N_NN')] [('ઉતારવા', 'V_VAUX_VNP')]
# [('સત્ય', 'N_NN'), ('થકી', 'PSP')] [('સત્ય', 'N_NN')]
# [('આપવું', 'V_VM'), ('છ', 'V_VAUX')] [('આપવામા', 'V_VAUX_VNP'), ('આવવું', 'V_VAUX'), ('છ', 'V_VAUX')]
# [('જુઓ', 'V_VM'), ('તો', 'CC_CCD')] [('જો', 'V_VAUX_VNP')]
# [('જ', 'RP_RPD'), ('ેના', 'V_VAUX_VNP')] [('જેમનાં', 'PR_PRL')]
# [("'", 'RD_PUNC'), ('', 'V_VAUX')] [('હ', 'V_VAUX')]
# [('એકેએક', 'JJ')] [('એકેક', 'QT_QTC')]
# [('ન', 'RP_NEG'), ('હ', 'V_VAUX'), (':', 'RD_PUNC')] [('નહોતું', 'RP_NEG'), ('.', 'RD_PUNC')]
# [('કેઃ', 'CC_CCS')] [('કે', 'CC_CCS'), (':', 'RD_PUNC')]
# [('રે', 'RP_RPD'), ('ેડ', 'N_NN')] [('રેડ', 'N_NN')]
# [('સાંભળનાર', 'V_VAUX_VNP'), ('તેઓ', 'PR_PRP')] [('સાંભળનારન', 'V_VAUX_VNP')]
# [('જ', 'RP_RPD'), ('ેવ', 'JJ')] [('જેમ', 'PSP')]
# [('રજપુત', 'N_NN')] [('જ્યાર', 'N_NST'), ('રજપૂત', 'N_NN')]
# [('થતું', 'V_VAUX_VNP')] [('થાય', 'V_VM'), ('છ', 'V_VAUX')]
# [('શાનું', 'PR_PRQ')] [('શા', 'PR_PRQ'), ('માટે', 'PSP')]
# [('પણ', 'RP_RPD'), ('બનવું', 'V_VM')] [('બનવું', 'V_VM')]
# [('દિ', 'N_NN'), ("'", 'RD_PUNC')] [('દિવસ', 'N_NN')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('પણ', 'CC_CCD'), ('સર્જનક્રિયાનુ', 'N_NN')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD'), ('સર્જનક્રિયા', 'N_NN')]
# [('નહિ', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('સૌરાષ્', 'N_NNP'), ('ને', 'CC_CCD')] [('સૌરાષ્ટ્ર', 'N_NNP')]
# [('મળેહળ', 'V_VM'), ('છ', 'V_VAUX')] [('મળેછ', 'V_VM')]
# [('મારડ', 'V_VM')] [('મારવું', 'V_VAUX_VNP')]
# [('ગ્યો', 'V_VM')] [('ગ', 'V_VM'), ('હ', 'V_VAUX')]
# [('પુગ્યા', 'V_VAUX_VNP')] [('પહોંચ્', 'V_VM'), ('.', 'RD_PUNC')]
# [('અંત', 'N_NN'), (':', 'N_NN'), ('કરણ', 'N_NN')] [('અંતઃકરણ', 'N_NN')]
# [('મત', 'N_NN')] [('મત', 'N_NN'), ('ધરાવ', 'V_VM')]
# [('કપડ', 'V_VM')] [('કપડાં', 'N_NN')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('ઉભય', 'N_NN')] [('બંને', 'JJ')]
# [('હ', 'V_VAUX'), ('ખરું', 'RP_RPD')] [('હોઈ', 'V_VAUX'), ('શકવું', 'V_VAUX'), ('છ', 'V_VAUX')]
# [('એ', 'PR_PRP')] [('એ', 'DM_DMD')]
# [(',', 'RD_PUNC'), ('વગૈરે', 'PSP')] [('વગેરે', 'PSP')]
# [('કરીન', 'V_VM')] [('કરવું', 'V_VM'), ('છ', 'V_VAUX')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('તેનું', 'DM_DMD')] [('તેના', 'DM_DMD')]
# [('એ', 'PR_PRP'), ('પણ', 'RP_RPD'), ('એ', 'PR_PRP')] [('તે', 'DM_DMD'), ('એ', 'PR_PRP')]
# [('હાજર', 'N_NN'), ('જ', 'RP_RPD'), ('ે', 'N_NN')] [('હાજરી', 'N_NN')]
# [('એનાં', 'DM_DMD')] [('એ', 'PR_PRP')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('ઉભય', 'JJ')] [('ઊભું', 'V_VM')]
# [('રહેવું', 'V_VM'), ('કરવું', 'V_VM')] [('રહ', 'V_VAUX')]
# [('ેવી', 'PSP')] [('જોઈએ', 'V_VM'), ('.', 'RD_PUNC')]
# [('તેનાં', 'DM_DMD')] [('તેને', 'DM_DMD')]
# [('તેનો', 'DM_DMD')] [('તેના', 'DM_DMD')]
# [('ન', 'RP_NEG')] [('નથી', 'RP_NEG')]
# [('તેઓ', 'PR_PRP'), ('તેના', 'DM_DMD')] [('તેઓના', 'PR_PRP')]
# [('તે', 'DM_DMD'), ('વખત', 'N_NN')] [('ત્યાર', 'N_NST')]
# [('તેના', 'DM_DMD')] [('તેનો', 'DM_DMD')]
# [('ઉભું', 'JJ')] [('ઊભું', 'V_VM')]
# [('પણ', 'CC_CCD')] [(',', 'RD_PUNC'), ('પરંતુ', 'CC_CCD')]
# [('ઘટ', 'V_VM'), ('છ', 'V_VAUX')] [('જોઈએ', 'V_VAUX')]
# [('બાળી', 'V_VM')] [('બળીન', 'V_VAUX_VNP')]
# [('કોઇ', 'DM_DMI'), ('કોઈ', 'DM_DMI')] [('કોઈક', 'DM_DMI')]
# [('મેળે', 'PR_PRF')] [('પાસે', 'PSP')]
# [('જોયાથી', 'V_VAUX_VNP')] [('જોયા', 'V_VAUX_VNP'), ('પછી', 'PSP')]
# [('નહિ', 'RP_NEG'), ('હોય', 'V_VAUX')] [('નથી', 'RP_NEG')]
# [('હ', 'V_VAUX')] [('છ', 'V_VAUX'), (',', 'RD_PUNC')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('ચાલ', 'V_VAUX_VNP'), ('"', 'RD_PUNC')] [('ચાલવું', 'V_VM'), ('છ', 'V_VAUX'), ('.', 'RD_PUNC')]
# [('ક્ષણ', 'N_NN'), ('પર', 'PSP')] [('ક્ષણભંગ', 'N_NN')]
# [('એવું', 'JJ'), ('વિશેષણોયુક્ત', 'JJ')] [('વિશેષણયુક્ત', 'JJ')]
# [('્રૅ', 'N_NN'), ('ેડી', 'V_VM')] [('્રૅડ', 'N_NN')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('હાલી', 'V_VM')] [('હાલીન', 'V_VAUX_VNP')]
# [('એ', 'DM_DMD')] [(',', 'RD_PUNC')]
# [('સાંભળવું', 'V_VM')] [('સંભળા', 'V_VAUX_VNP')]
# [('રંગકર્મ', 'N_NN'), ('જ', 'RP_RPD'), ('ેવી', 'PSP')] [('રંગકર્મી', 'N_NN'), ('અને', 'CC_CCD')]
# [('નહિ', 'RP_NEG')] [('નહીં', 'RP_NEG')]
# [('જુવોન', 'V_VM')] [('જુવ', 'V_VM'), ('ને', 'RP_RPD'), (',', 'RD_PUNC')]
# [('એ', 'PR_PRP')] [('તેનો', 'DM_DMD')]
# [('અમે', 'PR_PRP')] [('nuestros', 'RD_RDF')]
# [('ખુશી', 'N_NN'), ('થઇ', 'V_VAUX_VNP'), ('થઇ', 'V_VAUX_VNP')] [('ખુશી', 'N_NN')]
# [('ને', 'CC_CCD'), ('સુખદુ', 'N_NN'), (':', 'RD_PUNC'), ('ખ', 'N_NN')] [('અને', 'CC_CCD'), ('સુખદુઃખ', 'N_NN')]
# [('તૈ', 'RP_RPD')] [(',', 'RD_PUNC'), ('તેથી', 'PSP')]
# [('એઓ', 'PSP')] [('એવું', 'JJ')]
# [('આપ્યો', 'V_VM')] [('આપવું', 'V_VM'), ('હ', 'V_VAUX')]
# [('સાચ', 'N_NN')] [('સાચું', 'JJ')]
# [('નહોતું', 'RP_NEG')] [('નહોતી', 'RP_NEG')]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !errant_compare -hyp /content/drive/MyDrive/Smruti-GEC-for-Gujarati/hyp5k.m2 -ref /content/drive/MyDrive/Smruti-GEC-for-Gujarati/gold5k.m2 -cat 2
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at l3cube-pune/gujarati-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at l3cube-pune/gujarati-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 1 . બાળકો ક્રિકેટનો ખેલ રમી રહ્યા છે
#
# ===================== Span-Based Correction ======================
# Category       TP       FP       FN       P        R        F0.5
# ADJ            0        46       8        0.0      0.0      0.0
# ADJ:INFL       53       106      131      0.3333   0.288    0.3232
# ADP            3        47       8        0.06     0.2727   0.0711
# ADP:INFL       19       31       23       0.38     0.4524   0.3926
# ADV            0        4        0        0.0      1.0      0.0
# AUX            6        147      42       0.0392   0.125    0.0455
# CONJ           0        160      0        0.0      1.0      0.0
# DET            0        12       3        0.0      0.0      0.0
# MORPH          104      130      309      0.4444   0.2518   0.3855
# NOUN           5        166      68       0.0292   0.0685   0.033
# NOUN:INFL      175      189      610      0.4808   0.2229   0.3905
# NUM            7        23       18       0.2333   0.28     0.2414
# ORTH           2        191      1        0.0104   0.6667   0.0129
# OTHER          54       837      262      0.0606   0.1709   0.0696
# PART           0        33       0        0.0      1.0      0.0
# PRON           8        50       51       0.1379   0.1356   0.1375
# PRON:INFL      42       34       171      0.5526   0.1972   0.4062
# PUNCT          288      625      330      0.3154   0.466    0.3372
# SPELL          19       589      42       0.0312   0.3115   0.0381
# SPELL:ANUSVARA 139      350      229      0.2843   0.3777   0.2991
# SPELL:MATRA    307      158      286      0.6602   0.5177   0.6258
# VERB           0        63       10       0.0      0.0      0.0
# VERB:INFL      461      571      594      0.4467   0.437    0.4447
# VERB:TENSE     149      179      498      0.4543   0.2303   0.3803
# WO             53       15       519      0.7794   0.0927   0.314
#
# =========== Span-Based Correction ============
# TP	FP	FN	Prec	Rec	F0.5
# 1894	4756	4213	0.2848	0.3101	0.2895
# ==============================================

# %%
# !pwd

# %%
# %cd /content/errant-for-gujarati

# %%
# !git config --global user.email "vrund3626@gmail.com"
# !git config --global user.name "VGD3626"

# %%
# !git remote set-url origin https://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@github.com/VGD3626/errant-for-gujarati.git

# %%
# !git add .
# !git rm --cached -f errant-for-gujarati
# !git commit -m "updated the classifier"
# !git push origin main

# %%
# prompt: I have a file, named guj_gec.csv. read it using pandas and store sentence into c.txt and err_sentence into c.txt.

import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/guj-gec.csv')

# Assuming the column containing the sentences is named 'sentence' and the column with error sentences is 'err_sentence'
# Replace 'sentence' and 'err_sentence' with the actual column names in your CSV file
sentences_list = df['sentence'].tolist()
err_sentences_list = df['err_sentence'].tolist()

with open('/content/c.txt', 'w', encoding='utf-8') as f_c:
    for sentence in sentences_list:
        f_c.write(sentence + '\n')

with open('/content/o.txt', 'w', encoding='utf-8') as f_err:
    for err_sentence in err_sentences_list:
        f_err.write(err_sentence + '\n')


print("Sentences written to c.txt")
print("Error sentences written to err_sentence.txt")

# %%
import json

# Load the JSON data from the file
with open('/content/drive/MyDrive/Smruti-GEC-for-Gujarati/data/5k_errorneous_sentences.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Open the output files
with open('o.txt', 'w', encoding='utf-8') as o_file, \
     open('c.txt', 'w', encoding='utf-8') as c_file:

    # Iterate through the list of dictionaries in the JSON data
    for entry in data:
        # Write the 'input' value to o.txt
        o_file.write(entry['input'] + '\n')
        # Write the 'reference' value to c.txt
        c_file.write(entry['reference'] + '\n')

print("Input values written to o.txt")
print("Reference values written to c.txt")

# %%
# prompt: write the code which reads the json file and write 'input' field into one text file and 'reference' in other text file.

import json

# Specify the path to your JSON file
json_file_path = '/content/15k_err_sentences.json' # Replace with the actual path

# Specify the paths for the output text files
input_output_path = '/content/input.txt'
reference_output_path = '/content/reference.txt'

try:
    # Read the JSON file
    with open(json_file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # Open the output files for writing
    with open(input_output_path, 'w', encoding='utf-8') as input_f, \
         open(reference_output_path, 'w', encoding='utf-8') as reference_f:

        # Iterate through the data (assuming it's a list of dictionaries)
        # If your JSON structure is different, you'll need to adjust this loop
        if isinstance(data, list):
            for item in data:
                if 'input' in item:
                    input_f.write(str(item['input']) + '\n')
                if 'reference' in item:
                    reference_f.write(str(item['reference']) + '\n')
        elif isinstance(data, dict):
            # If the JSON is a single dictionary
            if 'input' in data:
                input_f.write(str(data['input']) + '\n')
            if 'reference' in data:
                reference_f.write(str(data['reference']) + '\n')
        else:
            print("JSON structure not recognized. Please ensure it's a list or dictionary.")


    print(f"'input' values written to {input_output_path}")
    print(f"'reference' values written to {reference_output_path}")

except FileNotFoundError:
    print(f"Error: The file '{json_file_path}' was not found.")
except json.JSONDecodeError:
    print(f"Error: Could not decode JSON from '{json_file_path}'. Please check the file format.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# prompt: read c.txt. Tokenize each line, combine tokens back, then write to the  file again. consider the case of punctuation while tokenizing

import string

def simple_tokenizer_with_punctuation(text):
    """
    A function to tokenize a string into a list of words,
    preserving punctuation as separate tokens.

    Args:
        text (str): The input string to tokenize.

    Returns:
        list: A list of words and punctuation (tokens).
    """
    tokens = []
    word = ""
    for char in text:
        if char.isspace():
            if word:
                tokens.append(word)
            word = ""
        elif char in string.punctuation:
            if word:
                tokens.append(word)
            word = ""
            tokens.append(char)
        else:
            word += char
    if word:
        tokens.append(word)
    return tokens

file_path = '/content/o.txt'
processed_lines = []

try:
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()  # Remove leading/trailing whitespace
            if line:  # Process non-empty lines
                tokens = simple_tokenizer_with_punctuation(line)
                combined_line = ' '.join(tokens)
                processed_lines.append(combined_line)
except FileNotFoundError:
    print(f"Error: The file {file_path} was not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# Write the processed lines back to the file
if processed_lines:
    try:
        with open(file_path, 'w', encoding='utf-8') as f:
            for processed_line in processed_lines:
                f.write(processed_line + '\n')
        print(f"Successfully processed and wrote to {file_path}")
    except Exception as e:
        print(f"An error occurred while writing to the file: {e}")
else:
    print(f"No lines were processed from {file_path}")

# %%
import matplotlib.pyplot as plt

# categories = [
#     "ADJ", "ADJ:INFL", "ADP", "ADP:INFL", "AUX", "CONJ", "DET", "MORPH", "NOUN",
#     "NOUN:INFL", "NUM", "ORTH", "OTHER", "PRON", "PRON:INFL", "PUNCT", "SPELL",
#     "SPELL:ANUSVARA", "SPELL:MATRA", "VERB", "VERB:FORM", "VERB:INFL", "VERB:TENSE", "WO"
# ]

# tp_counts = [
#     20, 78, 4, 3, 37, 5, 6, 433, 86,
#     493, 19, 167, 456, 46, 88, 67, 499,
#     303, 535, 17, 4, 580, 408, 441
# ]


# categories = [
#     "ADJ", "ADJ:INFL", "ADP", "ADP:INFL", "AUX", "CONJ", "DET", "MORPH", "NOUN",
#     "NOUN:INFL", "NUM", "ORTH", "OTHER", "PRON", "PRON:INFL", "PUNCT", "SPELL",
#     "SPELL:ANUSVARA", "SPELL:MATRA", "VERB", "VERB:FORM", "VERB:INFL", "VERB:TENSE", "WO", "X"
# ]

# tp_counts = [
#     20, 78, 4, 3, 37, 5, 6, 433, 87,
#     493, 19, 167, 453, 46, 88, 489, 72,
#     303, 535, 17, 4, 580, 408, 441, 7
# ]

# my eval set
# categories = [
#     "ADJ", "ADJ:INFL", "ADP", "ADV", "AUX", "CONJ", "DET", "MORPH", "NOUN",
#     "NOUN:INFL", "NUM", "ORTH", "OTHER", "PART", "PRON", "PRON:INFL", "PUNCT",
#     "SPELL", "SPELL:ANUSVARA", "SPELL:MATRA", "VERB", "VERB:INFL", "VERB:TENSE", "WO", "X"
# ]

# tp_counts = [
#     1, 14, 2, 2, 3, 5, 2, 19, 25,
#     19, 8, 5, 52, 1, 8, 5, 91,
#     62, 110, 38, 14, 52, 12, 18, 2
# ]

categories = [
    "ADJ", "ADJ:INFL", "ADP:INFL", "ADV", "CONJ", "DET", "MORPH", "NOUN",
    "NOUN:INFL", "NUM", "ORTH", "OTHER", "PART", "PRON", "PRON:INFL", "PUNCT",
    "SPELL", "SPELL:ANUSVARA", "SPELL:MATRA", "VERB", "VERB:INFL", "VERB:TENSE", "WO"
]

tp_counts = [
    1, 19, 2, 2, 5, 2, 21, 24,
    27, 8, 5, 53, 1, 8, 5, 105,
    50, 90, 35, 10, 68, 11, 18
]




percentages = [(tp / sum(tp_counts)) * 100 for tp in tp_counts]

# Sort both lists together by percentage (descending)
sorted_data = sorted(zip(percentages, categories), reverse=True)
sorted_percentages, sorted_categories = zip(*sorted_data)

# Plotting
fig, ax = plt.subplots(figsize=(12, 5))
bars = ax.bar(sorted_categories[:19], sorted_percentages[:19], color='mediumseagreen')
ax.set_xticklabels(sorted_categories, rotation=45, ha='right')
# ax.set_xlabel("Error Type", fontsize=16)
ax.set_ylabel("Samples (%)", fontsize=14)
# ax.set_title("Span-Based Correction: TP Distribution by Error Type (Percentage)")

# Show only x and y axis, no border
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Grid lines
ax.grid(axis='y', linestyle='--', alpha=0.3)
ax.grid(axis='x', linestyle='--', alpha=0.3)

# Add percentage labels above bars
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height:.2f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# categories = [
#     'ADJ', 'ADJ:INFL', 'ADP', 'ADP:INFL', 'ADV', 'AUX', 'CONJ', 'DET',
#     'MORPH', 'NOUN', 'NOUN:INFL', 'NUM', 'ORTH', 'OTHER', 'PART', 'PRON',
#     'PRON:INFL', 'PUNCT', 'SPELL:ANUSVARA', 'SPELL:MATRA', 'VERB', 'VERB:FORM',
#     'VERB:INFL', 'VERB:TENSE', 'WO'
# ]
# tp_values = [
#     13, 60, 9, 5, 2, 24, 6, 6,
#     480, 126, 705, 19, 176, 527, 4, 41,
#     53, 461, 308, 701, 39, 5,
#     520, 216, 444
# ]

categories = [
    "ADJ", "ADJ:INFL", "ADP", "ADP:INFL", "AUX", "DET", "MORPH", "NOUN",
    "NOUN:INFL", "NUM", "ORTH", "OTHER", "PRON", "PRON:INFL", "PUNCT",
    "SPELL", "SPELL:ANUSVARA", "SPELL:MATRA", "VERB", "VERB:INFL", "VERB:TENSE", "WO"
]

tp_values = [
    8, 184, 11, 42, 47, 3, 413, 73,
    785, 25, 2, 313, 59, 213, 608,
    60, 368, 593, 10, 1053, 649, 573
]


# Compute percentages
total = sum(tp_values)
percentages = [(tp / total) * 100 for tp in tp_values]

# Sort both lists together by percentage (descending)
sorted_data = sorted(zip(percentages, categories), reverse=True)
sorted_percentages, sorted_categories = zip(*sorted_data)

# Plotting
fig, ax = plt.subplots(figsize=(14, 6))
bars = ax.bar(sorted_categories[:19], sorted_percentages[:19], color='mediumseagreen')

# Font sizes updated
ax.set_xticklabels(sorted_categories, rotation=45, ha='right', fontsize=14)
# ax.set_xlabel("Error Type", fontsize=14)
ax.set_ylabel("Samples (%)", fontsize=14)
ax.tick_params(axis='y', labelsize=14)

# Show only x and y axis, no border
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Grid lines
ax.grid(axis='y', linestyle='--', alpha=0.3)
ax.grid(axis='x', linestyle='--', alpha=0.3)

# Add percentage labels above bars
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{height:.1f}%',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 3),
                textcoords="offset points",
                ha='center', va='bottom',
                fontsize=12)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Original data
# categories = ['ADJ', 'ADJ:INFL', 'ADP', 'AUX', 'DET', 'MORPH', 'NOUN', 'NOUN:INFL',
#               'NUM', 'ORTH', 'OTHER', 'PART', 'PRON', 'PRON:INFL', 'PUNCT', 'SPELL',
#               'SPELL:ANUSVARA', 'SPELL:MATRA', 'VERB', 'VERB:INFL', 'VERB:TENSE',
#               'WO', 'X']

# TP =  [0, 10, 1, 3, 0, 13, 8, 13, 3, 4, 18, 1, 3, 2, 35, 26, 54, 25, 7, 36, 6, 1, 1]
# FP =  [2, 2, 0, 0, 1, 3, 8, 2, 0, 4, 24, 0, 4, 1, 18, 20, 12, 3, 4, 10, 4, 0, 0]
# FN =  [0, 1, 0, 0, 1, 2, 7, 1, 0, 2, 11, 0, 2, 1, 23, 14, 19, 5, 2, 6, 1, 2, 0]


categories = ['ADJ', 'ADJ:INFL', 'ADP', 'AUX', 'DET', 'MORPH', 'NOUN', 'NOUN:INFL',
              'NUM', 'ORTH', 'OTHER', 'PART', 'PRON', 'PRON:INFL', 'PUNCT', 'SPELL',
              'SPELL:ANUSVARA', 'SPELL:MATRA', 'VERB', 'VERB:INFL', 'VERB:TENSE',
              'WO', 'X']

TP = [0, 10, 1, 3, 0, 13, 8, 13, 3, 4, 18, 1, 3, 2, 35, 26, 54, 25, 7, 36, 6, 1, 1]
FP = [2, 2, 0, 0, 1, 3, 8, 2, 0, 4, 24, 0, 4, 1, 18, 20, 12, 3, 4, 10, 4, 0, 0]
FN = [0, 1, 0, 0, 1, 2, 7, 1, 0, 2, 11, 0, 2, 1, 23, 14, 19, 5, 2, 6, 1, 2, 0]


# Compute total errors per category
total_errors = [tp + fp + fn for tp, fp, fn in zip(TP, FP, FN)]

# Combine all into a list of tuples for sorting
data = list(zip(categories, TP, FP, FN, total_errors))

# Sort by total_errors descending
data_sorted = sorted(data, key=lambda x: x[4], reverse=True)

# Unpack sorted data
categories_sorted, TP_sorted, FP_sorted, FN_sorted, _ = zip(*data_sorted[:19])

# Convert to lists for later computations
TP_sorted = list(TP_sorted)
FP_sorted = list(FP_sorted)
FN_sorted = list(FN_sorted)

# Compute percentages
totals_sorted = [tp + fp + fn for tp, fp, fn in zip(TP_sorted, FP_sorted, FN_sorted)]
corrected = [tp/tot*100 for tp, tot in zip(TP_sorted, totals_sorted)]
unchanged = [fn/tot*100 for fn, tot in zip(FN_sorted, totals_sorted)]
incorrect = [fp/tot*100 for fp, tot in zip(FP_sorted, totals_sorted)]


ind = np.arange(len(categories_sorted))
width = 0.7

plt.figure(figsize=(16, 8))
p1 = plt.bar(ind, corrected, width, label='Corrected', color='#76c7c0')
p2 = plt.bar(ind, unchanged, width, bottom=corrected, label='Unchanged', color='#ffcc00')
p3 = plt.bar(ind, incorrect, width, bottom=[i+j for i,j in zip(corrected, unchanged)], label='Incorrect', color='#ff6f69')

plt.ylabel('Percentage', fontsize=16)
# plt.title('Span-Based Correction Performance Sorted by Error Composition', fontsize=18)
plt.xticks(ind, categories_sorted, rotation=45, ha='right', fontsize=16)
plt.yticks(np.arange(0, 101, 10), fontsize=16)
plt.legend(fontsize=14, loc='upper right', ncol=1)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Categories (aligned across both datasets)
categories = [
    "ADJ", "ADJ:INFL", "ADP:INFL", "ADV", "CONJ", "DET", "MORPH", "NOUN",
    "NOUN:INFL", "NUM", "ORTH", "OTHER", "PART", "PRON", "PRON:INFL", "PUNCT",
    "SPELL", "SPELL:ANUSVARA", "SPELL:MATRA", "VERB", "VERB:INFL", "VERB:TENSE", "WO"
]

# Dataset 1 (first system, previously given)
tp_values_1 = [
    8, 184, 42, 0, 6, 3, 413, 73,
    785, 25, 2, 313, 4, 59, 213, 608,
    60, 368, 593, 10, 1053, 649, 573
]

# Dataset 2 (your new updated values)
tp_counts = [
    1, 19, 2, 2, 5, 2, 21, 24,
    27, 8, 5, 53, 1, 8, 5, 105,
    50, 90, 35, 10, 68, 11, 18
]

# Compute percentage values
total_1 = sum(tp_values_1)
total_2 = sum(tp_counts)

percentages_1 = [(v / total_1) * 100 for v in tp_values_1]
percentages_2 = [(v / total_2) * 100 for v in tp_counts]

# Sort based on dataset 1
sorted_data = sorted(zip(percentages_1, percentages_2, categories), reverse=True)
sorted_percentages_1, sorted_percentages_2, sorted_categories = zip(*sorted_data)

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(18, 6), sharey=True)

# First Plot
bars1 = axes[0].bar(sorted_categories[:19], sorted_percentages_1[:19], color='mediumseagreen')
axes[0].set_title("System 1", fontsize=16)
axes[0].set_ylabel("Samples (%)", fontsize=14)
axes[0].tick_params(axis='x', rotation=45, labelsize=12)
axes[0].grid(axis='y', linestyle='--', alpha=0.3)

# Annotate bars in first plot
for bar in bars1:
    height = bar.get_height()
    axes[0].annotate(f'{height:.1f}%',
                     xy=(bar.get_x() + bar.get_width() / 2, height),
                     xytext=(0, 3),
                     textcoords="offset points",
                     ha='center', va='bottom',
                     fontsize=10)

# Second Plot
bars2 = axes[1].bar(sorted_categories[:19], sorted_percentages_2[:19], color='mediumaquamarine')
axes[1].set_title("System 2", fontsize=16)
axes[1].tick_params(axis='x', rotation=45, labelsize=12)
axes[1].grid(axis='y', linestyle='--', alpha=0.3)

# Annotate bars in second plot
for bar in bars2:
    height = bar.get_height()
    axes[1].annotate(f'{height:.1f}%',
                     xy=(bar.get_x() + bar.get_width() / 2, height),
                     xytext=(0, 3),
                     textcoords="offset points",
                     ha='center', va='bottom',
                     fontsize=10)

# Remove top/right borders
for ax in axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()
